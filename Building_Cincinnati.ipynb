# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Cincinnati_placements_dict = {'2014':['FEDERER','FERRER','RAONIC','BENNETEAU',
                                      'MURRAY','WAWRINKA','FOGNINI','ROBREDO',
                              'DJOKOVIC','MONFILS','CILIC','JOHNSON','YOUZHNY','ISNER','LU','JANOWICZ',
                              'SIMON','POSPISIL','BECKER','BERDYCH','GINEPRI','KOHLSCHREIBER','DIMITROV','SOUSA',
                              'GULBIS','MATOSEVIC','BAUTISTA','VERDASCO','HEWITT','QUERREY','WARD','SEPPI'],
                             
                              '2015':['FEDERER','DJOKOVIC','DOLGOPOLOV','MURRAY',
                                      'WAWRINKA','LOPEZ','GASQUET','BERDYCH',
                              'GOFFIN','ANDERSON','DIMITROV','KARLOVIC','ROBREDO','CILIC','NADAL','JANOWICZ',
                              'PAIRE','BAUTISTA','FISH','CORIC','BELLUCCI','SOUSA','CHARDY','KOKKINAKIS',
                              'VERDASCO','SOCK','POSPISIL','TOMIC','DONALDSON','KLIZAN','SEPPI','QUERREY'],
                             
                              '2016':['CILIC','MURRAY','RAONIC','DIMITROV',
                                      'TOMIC','THIEM','CORIC','JOHNSON',
                              'ANDERSON','WAWRINKA','NADAL','SUGITA','NISHIKORI','BERDYCH','TSONGA','MONFILS',
                              'MONACO','DONALDSON','CUEVAS','ISNER','YOUZHNY','GRANOLLERS','OPELKA','MILLMAN',
                              'BAGHDATIS','GOFFIN','VERDASCO','GASQUET','KYRGIOS','LOPEZ','BENNETEAU','MAHUT'],
                             
                              '2017':['DIMITROV','KYRGIOS','ISNER','FERRER',
                                      'NADAL','THIEM','SUGITA','DONALDSON',
                              'VINOLAS','MANNARINO','DelPOTRO','CARRENO','TIAFOE','BASILASHVILI','KARLOVIC','KHACHANOV',
                              'GASQUET','FOGNINI','ZVEREV','LOPEZ','TSONGA','MischaZVEREV','PAUL','QUERREY',
                              'MULLER','HARRISON','KRUEGER','RAMANATHAN','TIPSAREVIC','FABBIANO','DOLGOPOLOV','SOUSA'],
                             
                              '2018':['DJOKOVIC','FEDERER','GOFFIN','CILIC',
                                      'WAWRINKA','DelPOTRO','CARRENO','RAONIC',
                              'MAYER','KYRGIOS','DIMITROV','ANDERSON','KHACHANOV','HAASE','SHAPOVALOV','FUCSOVICS',
                              'GOJOWCZYK','ZVEREV','CHUNG','MischaZVEREV','CHARDY','COPIL','MANNARINO','PAIRE',
                              'KLAHN','EDMUND','CORIC','POUILLE','GARCIA','QUERREY','JAZIRI','NISHIKORI'],
                             
                              '2019':['MEDVEDEV','GOFFIN','DJOKOVIC','GASQUET',
                                      'POUILLE','RUBLEV','BAUTISTA','NISHIOKA',
                              'CARRENO','FEDERER','KHACHANOV','STRUFF','KECMANOVIC','MANNARINO','SCHWARTZMAN','DeMINAUR',
                              'QUERREY','LONDERO','TSITSIPAS','NISHIKORI','ZVEREV','KYRGIOS','PAIRE','TIAFOE',
                              'ISNER','PELLA','OPELKA','DelBONIS','KUKUSHKIN','SHAPOVALOV','WAWRINKA','ALBOT'],
                             
                              '2020':['DJOKOVIC','RAONIC','BAUTISTA','TSITSIPAS',
                                      'STRUFF','MEDVEDEV','OPELKA','KRAJINOVIC',
                              'SANDGREN','BEDENE','ISNER','BERRETTINI','GOFFIN','KHACHANOV','FUCSOVICS','MURRAY',
                              'BERANKIS','THIEM','GIRON','ANDERSON','ZVEREV','RUUSUVUORI','CORIC','GASQUET',
                              'SCHWARTZMAN','CARRENO','SHAPOVALOV','DIMITROV','ALIASSIME','MILLMAN','FRITZ','EVANS'],
                             
                              '2021': lista_NaN }

# %%
Cincinnati_PLACEMENTS_DATA = pd.DataFrame( Cincinnati_placements_dict )
Cincinnati_PLACEMENTS_DATA = Cincinnati_PLACEMENTS_DATA.T
Cincinnati_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Cincinnati_PLACEMENTS_DATA
# Out:
#         winner  finalist       semi1      semi2        q1        q2        q3  \
# 2014   FEDERER    FERRER      RAONIC  BENNETEAU    MURRAY  WAWRINKA   FOGNINI
# 2015   FEDERER  DJOKOVIC  DOLGOPOLOV     MURRAY  WAWRINKA     LOPEZ   GASQUET
# 2016     CILIC    MURRAY      RAONIC   DIMITROV     TOMIC     THIEM     CORIC
# 2017  DIMITROV   KYRGIOS       ISNER     FERRER     NADAL     THIEM    SUGITA
# 2018  DJOKOVIC   FEDERER      GOFFIN      CILIC  WAWRINKA  DelPOTRO   CARRENO
# 2019  MEDVEDEV    GOFFIN    DJOKOVIC    GASQUET   POUILLE    RUBLEV  BAUTISTA
# 2020  DJOKOVIC    RAONIC    BAUTISTA  TSITSIPAS    STRUFF  MEDVEDEV    OPELKA
# 2021       NaN       NaN         NaN        NaN       NaN       NaN       NaN
#
#               q4        o1         o2  ...       32_7        32_8  \
# 2014     ROBREDO  DJOKOVIC    MONFILS  ...   DIMITROV       SOUSA
# 2015     BERDYCH    GOFFIN   ANDERSON  ...     CHARDY  KOKKINAKIS
# 2016     JOHNSON  ANDERSON   WAWRINKA  ...     OPELKA     MILLMAN
# ...

# %%
Cincinnati_PLACEMENTS_DATA.to_excel("Cincinnati_PLACEMENTS_DATA.xlsx")
