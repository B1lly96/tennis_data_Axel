# %%
import pandas as pd
import numpy as np 

matches_dataset_dict = {
            'OTT_QUIROZ_KARLOVIC_3_DELRAY_2021_HARD':[1,2,0,18],
            'OTT_FRATANGELO_TIAFOE_3_DELRAY_2021_HARD':[2,3,0,26],
            'OTT_MAGER_QUERREY_3_DELRAY_2021_HARD':[1,2,1,20],
            'OTT_KORDA_PAUL_3_DELRAY_2021_HARD':[1,3,0,27],
            'OTT_HURKACZ_GALAN_3_DELRAY_2021_HARD':[1,2,0,16],
            'OTT_MANNARINO_NORRIE_3_DELRAY_2021_HARD':[2,2,0,20],
            'OTT_MONTEIRO_ISNER_3_DELRAY_2021_HARD':[2,2,1,23],
            'OTT_HARRISON_GARIN_3_DELRAY_2021_HARD':[1,2,1,21],
            'QRT_HARRISON_MAGER_3_DELRAY_2021_HARD':[1,2,1,23],
            'QRT_NORRIE_TIAFOE_3_DELRAY_2021_HARD':[1,3,0,25],
            'QRT_QUIROZ_HURKACZ_3_DELRAY_2021_HARD':[2,2,0,20],
            'QRT_ISNER_KORDA_3_DELRAY_2021_HARD':[2,3,0,28],
            'SF_NORRIE_KORDA_3_DELRAY_2021_HARD':[2,2,0,21],
            'SF_HURKACZ_HARRISON_3_DELRAY_2021_HARD':[1,2,1,23],
            'F_HURKACZ_KORDA_3_DELRAY_2021_HARD':[1,2,0,18],
    
            'OTT_TRAVAGLIA_RUUSUVUORI_3_ANTALYA_2021_HARD':[1,2,1,22],
            'OTT_LAMASINE_BUBLIK_3_ANTALYA_2021_HARD':[2,2,0,18],
            'OTT_CELIKBILEK_BASILASHVILI_3_ANTALYA_2021_HARD':[2,2,1,23],
            'OTT_STRUFF_GRENIER_3_ANTALYA_2021_HARD':[3,0,0,0],
            'OTT_DeMINAUR_ANDREEV_3_ANTALYA_2021_HARD':[1,2,0,16],
            'OTT_FOGNINI_CHARDY_3_ANTALYA_2021_HARD':[2,3,1,39],
            'OTT_GOFFIN_KUHN_3_ANTALYA_2021_HARD':[1,2,0,14],
            'OTT_BERRETTINI_KUZMANOV_3_ANTALYA_2021_HARD':[1,2,0,17],
            'QRT_STRUFF_CHARDY_3_ANTALYA_2021_HARD':[2,3,1,31],
            'QRT_BASILASHVILI_DeMINAUR_3_ANTALYA_2021_HARD':[2,2,0,18],
            'QRT_GOFFIN_TRAVAGLIA_3_ANTALYA_2021_HARD':[1,2,0,17],
            'QRT_BUBLIK_BERRETTINI_3_ANTALYA_2021_HARD':[1,2,1,23],
            'SF_BUBLIK_CHARDY_3_ANTALYA_2021_HARD':[1,3,1,32],
            'SF_GOFFIN_DeMINAUR_3_ANTALYA_2021_HARD':[2,3,0,27],
            'F_BUBLIK_DeMINAUR_3_ANTALYA_2021_HARD':[4,0,0,2],
    
            'OTT_MONTEIRO_ALCARAZ_3_GreatOCEAN_2021_HARD':[1,2,1,22],
            'OTT_THOMPSON_VilellaMARTINEZ_3_GreatOCEAN_2021_HARD':[1,2,0,20],
            'OTT_BUBLIK_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[2,2,0,19],
            'OTT_CARUSO_KECMANOVIC_3_GreatOCEAN_2021_HARD':[2,3,1,37],
            'OTT_VandeZANDSCHULP_OPELKA_3_GreatOCEAN_2021_HARD':[1,2,1,26],
            'OTT_BEDENE_SINNER_3_GreatOCEAN_2021_HARD':[2,2,1,21],
            'OTT_CUEVAS_HURKACZ_3_GreatOCEAN_2021_HARD':[2,2,0,24],
            'OTT_ANDERSON_KHACHANOV_3_GreatOCEAN_2021_HARD':[2,2,1,22],
            'QRT_MONTEIRO_THOMPSON_3_GreatOCEAN_2021_HARD':[1,2,0,20],
            'QRT_SINNER_KECMANOVIC_3_GreatOCEAN_2021_HARD':[1,2,1,23],
            'QRT_HURKACZ_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[2,3,0,30],
            'QRT_KHACHANOV_VandeZANDSCHULP_3_GreatOCEAN_2021_HARD':[1,3,1,34],
            'SF_TRAVAGLIA_MONTEIRO_3_GreatOCEAN_2021_HARD':[1,2,0,19],
            'SF_KHACHANOV_SINNER_3_GreatOCEAN_2021_HARD':[2,3,1,36],
            'F_SINNER_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[1,2,1,23],
    
            'OTT_VESELY_BERANKIS_3_MurrayRIVER_2021_HARD':[1,2,0,18],
            'OTT_DUCKWORTH_MOUTET_3_MurrayRIVER_2021_HARD':[2,2,1,23],
            'OTT_GIRON_EVANS_3_MurrayRIVER_2021_HARD':[2,2,1,23],
            'OTT_FRITZ_CHARDY_3_MurrayRIVER_2021_HARD':[2,2,0,18],
            'OTT_CORIC_KYRGIOS_3_MurrayRIVER_2021_HARD':[1,2,0,19],
            'OTT_GERASIMOV_ALIASSIME_3_RiverMURRAY_2021_HARD':[2,3,1,31],
            'OTT_DIMITROV_POPYRIN_3_RiverMURRAY_2021_HARD':[1,3,1,32],
            'OTT_BOLT_WAWRINKA_3_RiverMURRAY_2021_HARD':[2,3,1,33],
            'QRT_EVANS_CORIC_3_RiverMURRAY_2021_HARD':[1,2,1,25],
            'QRT_ALIASSIME_VESELY_3_RiverMURRAY_2021_HARD':[3,1,1,13],
            'QRT_DIMITROV_MOUTET_3_MurrayRIVER_2021_HARD':[2,2,0,20],
            'QRT_WAWRINKA_CHARDY_3_MurrayRIVER_2021_HARD':[4,0,0,0],
            'SF_EVANS_CHARDY_3_MurrayRIVER_2021_HARD':[1,2,0,16],
            'SF_MOUTET_ALIASSIME_3_MurrayRIVER_2021_HARD':[2,2,0,15],
            'F_ALIASSIME_EVANS_3_MurrayRIVER_2021_HARD':[2,2,0,17],
    
            'OTT_ANDREEV_POPYRIN_3_SINGAPORE_2021_HARD':[2,3,0,28],
            'OTT_UCHIYAMA_KWON_3_SINGAPORE_2021_HARD':[2,2,0,19],
            'OTT_ALBOT_HANFMANN_3_SINGAPORE_2021_HARD':[1,3,1,35],
            'OTT_CRESSY_NISHIOKA_3_SINGAPORE_2021_HARD':[2,2,0,18],
            'OTT_BUBLIK_CELIKBILEK_3_SINGAPORE_2021_HARD':[1,2,0,16],
            'OTT_DANIEL_CILIC_3_SINGAPORE_2021_HARD':[2,2,0,22],
            'OTT_EBDEN_MILLMAN_3_SINGAPORE_2021_HARD':[1,2,0,17],
            'OTT_MANNARINO_MARCORA_3_SINGAPORE_2021_HARD':[1,2,0,21],
            'QRT_POPYRIN_EBDEN_3_SINGAPORE_2021_HARD':[1,2,1,23],
            'QRT_NISHIOKA_BUBLIK_3_SINGAPORE_2021_HARD':[2,2,0,17],
            'QRT_CILIC_KWON_3_SINGAPORE_2021_HARD':[1,3,0,28],
            'QRT_MANNARINO_ALBOT_3_SINGAPORE_2021_HARD':[2,2,0,19],
            'SF_BUBLIK_ALBOT_3_SINGAPORE_2021_HARD':[1,3,0,27],
            'SF_CILIC_POPYRIN_3_SINGAPORE_2021_HARD':[2,2,1,26],
            'F_POPYRIN_BUBLIK_3_SINGAPORE_2021_HARD':[1,3,0,24],
    
            'OTT_GOJOWCZYK_VESELY_3_MONTPELLER_2021_HARD':[1,3,1,35],
            'OTT_GERASIMOV_BEDENE_3_MONTPELLIER_2021_HARD':[1,2,1,23],
            'OTT_SONEGO_KORDA_3_MONTPELLIER_2021_HARD':[1,2,0,17],
            'OTT_GRIEKSPOOR_HUMBERT_3_MONTPELLIER_2021_HARD':[2,3,1,39],
            'OTT_FOKINA_HURKACZ_3_MONTPELLIER_2021_HARD':[1,2,0,20],
            'OTT_LAJOVIC_NOVAK_3_MONTPELLIER_2021_HARD':[2,2,1,25],
            'OTT_BONZI_GOFFIN_3_MONTPELLIER_2021_HARD':[2,3,0,32],
            'OTT_BAUTISTA_BARRERE_3_MONTPELLIER_2021_HARD':[1,2,0,15],
            'QRT_GOJOWCZYK_NOVAK_3_MONTPELLIER_2021_HARD':[1,2,0,17],
            'QRT_FOKINA_GERASIMOV_3_MONTPELLIER_2021_HARD':[2,3,0,32],
            'QRT_GOFFIN_SONEGO_3_MONTPELLIER_2021_HARD':[1,2,0,20],
            'QRT_BAUTISTA_HUMBERT_3_MONTPELLIER_2021_HARD':[1,2,0,18],
            'SF_GERASIMOV_GOFFIN_3_MONTPELLIER_2021_HARD':[2,3,0,28],
            'SF_GOJOWCZYK_BAUTISTA_3_MONTPELLIER_2021_HARD':[2,2,0,19],
            'F_GOFFIN_BAUTISTA_3_MONTPELLIER_2021_HARD':[1,3,0,30],
    
            'OTT_PAUL_BUBLIK_3_ROTTERDAM_2021_HARD':[1,3,1,29],
            'OTT_NISHIKORI_DeMINAUR_3_ROTTERDAM_2021_HARD':[1,3,0,29],
            'OTT_NORRIE_KHACHANOV_3_ROTTERDAM_2021_HARD':[2,2,0,16],
            'OTT_FOKINA_FUCSOVICS_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'OTT_LAJOVIC_CORIC_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'OTT_CHARDY_GOFFIN_3_ROTTERDAM_2021_HARD':[1,2,1,26],
            'OTT_MURRAY_RUBLEV_3_ROTTERDAM_2021_HARD':[2,2,0,20],
            'OTT_TSITSIPAS_HURKACZ_3_ROTTERDAM_2021_HARD':[1,3,0,32],
            'QRT_FUCSOVICS_PAUL_3_ROTTERDAM_2021_HARD':[1,2,0,19],
            'QRT_NISHIKORI_CORIC_3_ROTTERDAM_2021_HARD':[2,2,1,26],
            'QRT_RUBLEV_CHARDY_3_ROTTERDAM_2021_HARD':[1,3,1,36],
            'QRT_TSITSIPAS_KHACHANOV_3_ROTTERDAM_2021_HARD':[1,3,0,31],
            'SF_CORIC_FUCSOVICS_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'SF_RUBLEV_TSITSIPAS_ROTTERDAM_2021_HARD':[1,2,1,22],
            'F_FUCSOVICS_RUBLEV_3_ROTTERDAM_2021_HARD':[2,2,1,23],
                        
            'OTT_HARRIS_FUCSOVICS_3_DOHA_2021_HARD':[2,3,1,31],
            'OTT_BASILASHVILI_JAZIRI_3_DOHA_2021_HARD':[1,2,0,16],
            'OTT_GOFFIN_FRITZ_3_DOHA_2021_HARD':[2,3,1,32],
            'OTT_BAUTISTA_BUBLIK_3_DOHA_2021_HARD':[1,2,0,19],
            'OTT_SHAPOVALOV_POSPISIL_3_DOHA_2021_HARD':[1,2,0,22],
            'OTT_GASQUET_RUBLEV_3_DOHA_2021_HARD':[4,0,0,0],
            'OTT_FEDERER_EVANS_3_DOHA_2021_HARD':[1,3,1,34],
            'OTT_THIEM_KARATSEV_3_DOHA_2021_HARD':[1,3,1,30],
            'QRT_SHAPOVALOV_FRITZ_3_DOHA_2021_HARD':[2,3,0,33],
            'QRT_RUBLEV_FUCSOVICS_3_DOHA_2021_HARD':[3,0,0,0],
            'QRT_BASILASHVILI_FEDERER_3_DOHA_2021_HARD':[1,3,0,28],
            'QRT_BAUTISTA_THIEM_3_DOHA_2021_HARD':[1,3,1,31],
            'SF_FRITZ_BASILASHVILI_3_DOHA_2021_HARD':[2,2,1,20],
            'SF_BAUTISTA_RUBLEV_3_DOHA_2021_HARD':[1,2,0,18],
            'F_BAUTISTA_BASILASHVILI_3_DOHA_2021_HARD':[2,2,1,21],
                        
            'OTT_HERBERT_NORRIE_3_MARSIGLIA_2021_HARD':[1,2,0,19],
            'OTT_RUUSUVUORI_EBDEN_3_MARSIGLIA_2021_HARD':[2,2,0,16],
            'OTT_FOKINA_RINDERKNECH_3_MARSIGLIA_2021_HARD':[2,3,0,24],
            'OTT_SINNER_GASTON_3_MARSIGLIA_2021_HARD':[1,2,0,17],
            'OTT_HUMBERT_TSONGA_3_MARSIGLIA_2021_HARD':[1,2,0,19],
            'OTT_KHACHANOV_McDONALD_3_MARSIGLIA_2021_HARD':[1,2,1,23],
            'OTT_POUILLE_TSITSIPAS_3_MARSIGLIA_2021_HARD':[2,2,0,17],
            'OTT_MEDVEDEV_GERASIMOV_3_MARSIGLIA_2021_HARD':[1,2,0,18],
            'QRT_RINDERKNECH_HUMBERT_3_MARSIGLIA_2021_HARD':[2,3,1,35],
            'QRT_EBDEN_KHACHANOV_3_MARSIGLIA_2021_HARD':[1,3,0,28],
            'QRT_HERBERT_TSITSIPAS_3_MARSIGLIA_2021_HARD':[1,3,1,31],
            'QRT_SINNER_MEDVEDEV_3_MARSIGLIA_2021_HARD':[2,2,0,18],
            'SF_HERBERT_HUMBERT_3_MARSIGLIA_2021_HARD':[1,2,0,17],
            'SF_MEDVEDEV_EBDEN_3_MARSIGLIA_2021_HARD':[3,2,0,13],
            'F_MEDVEDEV_HERBERT_3_MARSIGLIA_2021_HARD':[1,3,1,33],
                        
            'OTT_NISHIKORI_BEDENE_3_DUBAI_2021_HARD':[1,2,0,20],
            'OTT_SONEGO_KARATSEV_3_DUBAI_2021_HARD':[2,3,0,28],
            'OTT_KRAJINOVIC_HARRIS_3_DUBAI_2021_HARD':[2,2,1,23],
            'OTT_FUCSOVICS_LAJOVIC_3_DUBAI_2021_HARD':[1,3,0,27],
            'OTT_CHARDY_KHACHANOV_3_DUBAI_2021_HARD':[1,3,1,33],
            'OTT_BAUTISTA_SINNER_3_DUBAI_2021_HARD':[2,3,0,31],
            'OTT_SHAPOVALOV_HURKACZ_3_DUBAI_2021_HARD':[1,2,0,19],
            'OTT_RUBLEV_FRITZ_3_DUBAI_2021_HARD':[1,2,0,16],
            'QRT_HARRIS_NISHIKORI_3_DUBAI_2021_HARD':[1,3,0,25],
            'QRT_KARATSEV_SINNER_3_DUBAI_2021_HARD':[1,3,1,30],
            'QRT_CHARDY_SHAPOVALOV_3_DUBAI_2021_HARD':[2,2,0,22],
            'QRT_RUBLEV_FUCSOVICS_3_DUBAI_2021_HARD':[1,2,0,20],
            'SF_HARRIS_SHAPOVALOV_3_DUBAI_2021_HARD':[1,3,1,36],
            'SF_RUBLEV_KARATSEV_3_DUBAI_2021_HARD':[2,3,0,28],
            'F_KARATSEV_HARRIS_3_DUBAI_2021_HARD':[1,2,0,17],
                        
            'OTT_MUSETTI_TIAFOE_3_ACAPULCO_2021_HARD':[1,3,1,30],
            'OTT_GRIEKSPOOR_RUUD_3_ACAPULCO_2021_HARD':[2,3,1,32],
            'OTT_ALIASSIME_KORDA_3_ACAPULCO_2021_HARD':[1,2,0,19],
            'OTT_NORRIE_FOGNINI_3_ACAPULCO_2021_HARD':[1,2,0,19],
            'OTT_DIMITROV_KECMANOVIC_3_ACAPULCO_2021_HARD':[1,2,0,18],
            'OTT_RAONIC_KOEPFER_3_ACAPULCO_2021_HARD':[2,2,0,18],
            'OTT_DJERE_ZVEREV_3_ACAPULCO_2021_HARD':[2,2,0,19],
            'OTT_TSITSIPAS_ISNER_3_ACAPULCO_2021_HARD':[1,2,0,17],
            'QRT_KOEPFER_NORRIE_3_ACAPULCO_2021_HARD':[1,2,0,22],
            'QRT_MUSETTI_DIMITROV_3_ACAPULCO_2021_HARD':[1,2,1,23],
            'QRT_ZVEREV_RUUD_3_ACAPULCO_2021_HARD':[3,0,0,0],
            'QRT_TSITSIPAS_ALIASSIME_3_ACAPULCO_2021_HARD':[1,3,0,31],
            'SF_KOEPFER_ZVEREV_3_ACAPULCO_2021_HARD':[2,2,1,23],
            'SF_MUSETTI_TSITSIPAS_3_ACAPULCO_2021_HARD':[2,2,0,16],
            'F_ZVEREV_TSITSIPAS_3_ACAPULCO_2021_HARD':[1,2,1,23],
                        
            'OTT_FRITZ_BUBLIK_3_MIAMI_2021_HARD':[2,3,1,32],
            'OTT_RUUSUVUORI_SINNER_3_MIAMI_2021_HARD':[2,2,0,17],
            'OTT_HURKACZ_RAONIC_3_MIAMI_2021_HARD':[1,3,1,32],
            'OTT_BAUTISTA_ISNER_3_MIAMI_2021_HARD':[1,3,1,32],
            'OTT_SCHWARTZMAN_KORDA_3_MIAMI_2021_HARD':[2,3,0,31],
            'OTT_RUBLEV_CILIC_3_MIAMI_2021_HARD':[1,2,0,20],
            'OTT_SONEGO_TSITSIPAS_3_MIAMI_2021_HARD':[2,2,1,21],
            'OTT_TIAFOE_MEDVEDEV_3_MIAMI_2021_HARD':[2,2,0,19],
            'QRT_SINNER_BUBLIK_3_MIAMI_2021_HARD':[1,2,1,23],
            'QRT_KORDA_RUBLEV_3_MIAMI_2021_HARD':[2,2,1,25],
            'QRT_HURKACZ_TSITSIPAS_3_MIAMI_2021_HARD':[1,3,0,27],
            'QRT_BAUTISTA_MEDVEDEV_3_MIAMI_2021_HARD':[1,2,0,18],
            'SF_BAUTISTA_SINNER_3_MIAMI_2021_HARD':[2,3,0,32],
            'SF_HURKACZ_RUBLEV_3_MIAMI_2021_HARD':[1,2,0,19],
            'F_HURKACZ_SINNER_3_MIAMI_2021_HARD':[1,2,1,23],
                        
            'OTT_FUCSOVICS_ILKEL_3_DOHA_2020_HARD':[1,2,0,17],
            'OTT_BUBLIK_BEDENE_3_DOHA_2020_HARD':[2,2,0,21],
            'OTT_KRAJINOVIC_VERDASCO_3_DOHA_2020_HARD':[2,3,0,28],
            'OTT_DJERE_HERBERT_3_DOHA_2020_HARD':[2,2,0,16],
            'OTT_MOUTET_RAONIC_3_DOHA_2020_HARD':[1,2,1,26],
            'OTT_TSONGA_KECMANOVIC_3_DOHA_2020_HARD':[2,2,1,20],
            'OTT_RUBLEV_KUKUSHKIN_3_DOHA_2020_HARD':[1,2,0,18],
            'OTT_CHARDY_WAWRINKA_3_DOHA_2020_HARD':[2,2,0,19],
            'QRT_MOUTET_VERDASCO_3_DOHA_2020_HARD':[1,3,0,30],
            'QRT_FUCSOVICS_KECMANOVIC_3_DOHA_2020_HARD':[2,2,0,14],
            'QRT_HERBERT_RUBLEV_3_DOHA_2020_HARD':[2,2,0,19],
            'QRT_WAWRINKA_BEDENE_3_DOHA_2020_HARD':[1,2,0,19],
            'SF_RUBLEV_KECMANOVIC_3_DOHA_2020_HARD':[1,2,0,16],
            'SF_MOUTET_WAWRINKA_3_DOHA_2020_HARD':[1,3,0,30],
            'F_MOUTET_RUBLEV_3_DOHA_2020_HARD':[2,2,1,21],
                       
            'OTT_VINOLAS_MUNAR_3_ADELAIDE_2020_HARD':[1,2,1,22],
            'OTT_CUEVAS_PAUL_3_ADELAIDE_2020_HARD':[2,2,0,15],
            'OTT_DJERE_HARRIS_3_ADELAIDE_2020_HARD':[2,2,1,22],
            'OTT_EVANS_BUBLIK_3_ADELAIDE_2020_HARD':[1,2,0,20],
            'OTT_BOLT_STRUFF_3_ADELAIDE_2020_HARD':[1,2,0,19],
            'OTT_CARRENO_CHARDY_3_ADELAIDE_2020_HARD':[1,2,0,17],
            'OTT_QUERREY_RUBLEV_3_ADELAIDE_2020_HARD':[2,2,0,18],
            'OTT_DUCKWORTH_ALIASSIME_3_ADELAIDE_2020_HARD':[2,2,1,22],
            'QRT_PAUL_VINOLAS_3_ADELAIDE_2020_HARD':[1,2,0,19],
            'QRT_CARRENO_HARRIS_3_ADELAIDE_2020_HARD':[2,2,0,18],
            'QRT_EVANS_RUBLEV_3_ADELAIDE_2020_HARD':[2,3,0,28],
            'QRT_BOLT_ALIASSIME_3_ADELAIDE_2020_HARD':[2,2,0,15],
            'SF_HARRIS_PAUL_3_ADELAIDE_2020_HARD':[1,3,1,32],
            'SF_RUBLEV_ALIASSIME_3_ADELAIDE_2020_HARD':[1,3,1,36],
            'F_HARRIS_RUBLEV_3_ADELAIDE_2020_HARD':[2,2,0,15],
                       
            'OTT_CECCHINATO_HUMBERT_3_AUCKLAND_2020_HARD':[2,2,0,17],
            'OTT_SEPPI_EDMUND_3_AUCKLAND_2020_HARD':[2,2,1,22],
            'OTT_YMER_HURKACZ_3_AUCKLAND_2020_HARD':[2,2,1,21],
            'OTT_MONTEIRO_PAIRE_3_AUCKLAND_2020_HARD':[2,3,0,29],
            'OTT_ISNER_SANDGREN_3_AUCKLAND_2020_HARD':[1,3,1,35],
            'OTT_KHACHANOV_MILLMAN_3_AUCKLAND_2020_HARD':[2,3,0,28],
            'OTT_SHAPOVALOV_POSPISIL_3_AUCKLAND_2020_HARD':[1,2,1,23],
            'OTT_LOPEZ_FOGNINI_3_AUCKLAND_2020_HARD':[1,3,0,28],
            'QRT_LOPEZ_HURKACZ_3_AUCKLAND_2020_HARD':[2,3,1,33],
            'QRT_MILLMAN_PAIRE_3_AUCKLAND_2020_HARD':[2,3,0,26],
            'QRT_EDMUND_ISNER_3_AUCKLAND_2020_HARD':[2,2,1,26],
            'QRT_HUMBERT_SHAPOVALOV_3_AUCKLAND_2020_HARD':[1,2,0,22],
            'SF_HURKACZ_PAIRE_3_AUCKLAND_2020_HARD':[2,3,1,31],
            'SF_HUMBERT_ISNER_3_AUCKLAND_2020_HARD':[1,2,1,23],
            'F_PAIRE_HUMBERT_3_AUCKLAND_2020_HARD':[2,3,1,35],
                       
            'OTT_GERASIMOV_MILOJEVIC_3_PUNE_2020_HARD':[1,3,0,25],
            'OTT_VESELY_CARUSO_3_PUNE_2020_HARD':[1,2,1,23],
            'OTT_DUCKWORTH_DANIEL_3_PUNE_2020_HARD':[1,3,1,35],
            'OTT_SUGITA_TROICKI_3_PUNE_2020_HARD':[3,0,0,0],
            'OTT_KWON_GUNNESWARAN_3_PUNE_2020_HARD':[1,2,1,22],
            'OTT_IVASHKA_TRAVAGLIA_3_PUNE_2020_HARD':[1,2,1,26],
            'OTT_STEBE_BERANKIS_3_PUNE_2020_HARD':[2,2,1,20],
            'OTT_PAIRE_MARCORA_3_PUNE_2020_HARD':[2,2,0,20],
            'QRT_VESELY_IVASHKA_3_PUNE_2020_HARD':[1,3,1,28],
            'QRT_MARCORA_DUCKWORTH_3_PUNE_2020_HARD':[2,2,1,22],
            'QRT_KWON_GERASIMOV_3_PUNE_2020_HARD':[2,3,1,33],
            'QRT_SUGITA_BERANKIS_3_PUNE_2020_HARD':[2,3,1,31],
            'SF_GERASIMOV_DUCKWORTH_3_PUNE_2020_HARD':[1,2,1,23],
            'SF_VESELY_BERANKIS_3_PUNE_2020_HARD':[1,3,1,39],
            'F_GERASIMOV_VESELY_3_PUNE_2020_HARD':[2,3,1,34],
                       
            'OTT_GOMBOS_RUUSUVUORI_3_MONTPELLIER_2020_HARD':[1,2,0,22],
            'OTT_LOPEZ_GASQUET_3_MONTPELLIER_2020_HARD':[2,3,1,31],
            'OTT_YMER_KRAJINOVIC_3_MONTPELLIER_2020_HARD':[2,2,0,14],
            'OTT_ALIASSIME_HERBERT_3_MONTPELLIER_2020_HARD':[2,2,1,25],
            'OTT_DIMITROV_BARRERE_3_MONTPELLIER_2020_HARD':[2,3,1,35],
            'OTT_SHAPOVALOV_POSPISIL_3_MONTPELLIER_2020_HARD':[2,2,0,17],
            'OTT_GOFFIN_BUBLIK_3_MONTPELLIER_2020_HARD':[1,2,1,22],
            'OTT_MONFILS_MANNARINO_3_MONTPELLIER_2020_HARD':[1,3,0,27],
            'QRT_GASQUET_POSPISIL_3_MONTPELLIER_2020_HARD':[4,2,0,8],
            'QRT_BARRERE_KRAJINOVIC_3_MONTPELLIER_2020_HARD':[2,2,0,20],
            'QRT_GOFFIN_HERBERT_3_MONTPELLIER_2020_HARD':[1,2,1,23],
            'QRT_GOMBOS_MONFILS_3_MONTPELLIER_2020_HARD':[2,2,0,19],
            'SF_POSPISIL_GOFFIN_3_MONTPELLIER_2020_HARD':[1,3,0,28],
            'SF_MONFILS_KRAJINOVIC_3_MONTPELLIER_2020_HARD':[1,2,1,21],
            'F_MONFILS_POSPISIL_3_MONTPELLIER_2020_HARD':[1,2,0,21],
                       
            'OTT_POSPISIL_KRAJINOVIC_3_ROTTERDAM_2020_HARD':[2,2,1,23],
            'OTT_KHACHANOV_EVANS_3_ROTTERDAM_2020_HARD':[2,3,0,29],
            'OTT_ALIASSIME_DIMITROV_3_ROTTERDAM_2020_HARD':[1,2,0,18],
            'OTT_BUBLIK_RUBLEV_3_ROTTERDAM_2020_HARD':[2,2,0,21],
            'OTT_BAUTISTA_CARRENO_3_ROTTERDAM_2020_HARD':[2,3,1,31],
            'OTT_SINNER_GOFFIN_3_ROTTERDAM_2020_HARD':[1,2,1,25],
            'OTT_MONFILS_SIMON_3_ROTTERDAM_2020_HARD':[1,2,0,17],
            'OTT_BEDENE_TSITSIPAS_3_ROTTERDAM_2020_HARD':[1,2,0,22],
            'QRT_CARRENO_SINNER_3_ROTTERDAM_2020_HARD':[1,3,1,34],
            'QRT_BEDENE_ALIASSIME_3_ROTTERDAM_2020_HARD':[2,2,1,23],
            'QRT_KRAJINOVIC_RUBLEV_3_ROTTERDAM_2020_HARD':[1,2,1,23],
            'QRT_EVANS_MONFILS_3_ROTTERDAM_2020_HARD':[2,2,1,21],
            'SF_CARRENO_ALIASSIME_3_ROTTERDAM_2020_HARD':[2,2,1,23],
            'SF_MONFILS_KRAJINOVIC_3_ROTTERDAM_2020_HARD':[1,2,1,23],
            'F_MONFILS_ALIASSIME_3_ROTTERDAM_2020_HARD':[1,2,0,18],

            'OTT_SEPPI_JOHNSON_3_NewYORK_2020_HARD':[1,2,1,22],
            'OTT_KOEPFER_EDMUND_3_NewYORK_2020_HARD':[2,2,0,18],
            'OTT_NORRIE_JUNG_3_NewYORK_2020_HARD':[2,2,0,20],
            'OTT_KECMANOVIC_LORENZI_3_NewYORK_2020_HARD':[1,2,0,18],
            'OTT_HUMBERT_GIRON_3_NewYORK_2020_HARD':[1,2,0,13],
            'OTT_OPELKA_NISHIOKA_3_NewYORK_2020_HARD':[1,2,0,20],
            'OTT_RAONIC_KWON_3_NewYORK_2020_HARD':[2,3,1,36],
            'OTT_THOMPSON_ISNER_3_NewYORK_2020_HARD':[1,3,1,35],
            'QRT_SEPPI_THOMPSON_3_NewYORK_2020_HARD':[1,3,1,30],
            'QRT_EDMUND_KWON_3_NewYORK_2020_HARD':[1,3,1,30],
            'QRT_KECMANOVIC_HUMBERT_3_NewYORK_2020_HARD':[1,3,0,27],
            'QRT_OPELKA_JUNG_3_NewYORK_2020_HARD':[2,3,0,32],
            'SF_SEPPI_JUNG_3_NewYORK_2020_HARD':[1,2,0,17],
            'SF_KECMANOVIC_EDMUND_3_NewYORK_2020_HARD':[2,2,0,17],
            'F_SEPPI_EDMUND_3_NewYORK_2020_HARD':[2,2,0,19],

            'OTT_SIMON_BEDENE_3_MARSIGLIA_2020_HARD':[1,2,1,23],
            'OTT_POSPISIL_HURKACZ_3_MARSIGLIA_2020_HARD':[1,2,0,19],
            'OTT_ALIASSIME_HERBERT_3_MARSIGLIA_2020_HARD':[1,3,1,32],
            'OTT_PAIRE_BUBLIK_3_MARSIGLIA_2020_HARD':[2,3,0,29],
            'OTT_CILIC_SHAPOVALOV_3_MARSIGLIA_2020_HARD':[2,3,0,28],
            'OTT_GERASIMOV_GOFFIN_3_MARSIGLIA_2020_HARD':[1,2,1,23],
            'OTT_YMER_TSITSIPAS_3_MARSIGLIA_2020_HARD':[2,2,0,16],
            'OTT_MEDVEDEV_SINNER_3_MARSIGLIA_2020_HARD':[1,3,0,22],
            'QRT_ALIASSIME_GERASIMOV_3_MARSIGLIA_2020_HARD':[1,2,0,20],
            'QRT_BUBLIK_SHAPOVALOV_3_MARSIGLIA_2020_HARD':[1,3,0,31],
            'QRT_TSITSIPAS_POSPISIL_3_MARSIGLIA_2020_HARD':[1,2,0,21],
            'QRT_SIMON_MEDVEDEV_3_MARSIGLIA_2020_HARD':[1,2,0,16],
            'SF_ALIASSIME_SIMON_3_MARSIGLIA_2020_HARD':[1,2,1,25],
            'SF_TSITSIPAS_BUBLIK_3_MARSIGLIA_2020_HARD':[1,2,0,21],
            'F_ALIASSIME_TSITSIPAS_3_MARSIGLIA_2020_HARD':[2,2,0,19],

            'OTT_TIAFOE_PAUL_3_DELRAY_2020_HARD':[1,2,1,25],
            'OTT_NISHIOKA_RUBIN_3_DELRAY_2020_HARD':[1,2,0,15],
            'OTT_NORRIE_NAKASHIMA_3_DELRAY_2020_HARD':[2,2,0,20],
            'OTT_KWON_HARRISON_3_DELRAY_2020_HARD':[1,3,1,32],
            'OTT_SOCK_JOHNSON_3_DELRAY_2020_HARD':[2,3,0,29],
            'OTT_KECMANOVIC_HUMBERT_3_DELRAY_2020_HARD':[2,2,1,23],
            'OTT_OPELKA_McDONALD_3_DELRAY_2020_HARD':[1,2,0,19],
            'OTT_STEBE_RAONIC_3_DELRAY_2020_HARD':[2,2,0,21],
            'QRT_NAKASHIMA_NISHIOKA_3_DELRAY_2020_HARD':[2,3,1,32],
            'QRT_TIAFOE_HUMBERT_3_DELRAY_2020_HARD':[2,2,0,15],
            'QRT_OPELKA_KWON_3_DELRAY_2020_HARD':[1,2,0,19],
            'QRT_JOHNSON_RAONIC_3_DELRAY_2020_HARD':[2,2,1,22],
            'SF_NISHIOKA_HUMBERT_3_DELRAY_2020_HARD':[1,3,0,23],
            'SF_OPELKA_RAONIC_3_DELRAY_2020_HARD':[1,3,1,32],
            'F_NISHIOKA_OPELKA_3_DELRAY_2020_HARD':[2,3,1,33],

            'OTT_STRUFF_BASILASHVILI_3_DUBAI_2020_HARD':[1,2,0,13],
            'OTT_EVANS_HERBERT_3_DUBAI_2020_HARD':[1,3,1,34],
            'OTT_GASQUET_PAIRE_3_DUBAI_2020_HARD':[1,2,0,20],
            'OTT_NOVAK_KHACHANOV_3_DUBAI_2020_HARD':[2,2,0,19],
            'OTT_KRAJINOVIC_RUBLEV_3_DUBAI_2020_HARD':[2,2,1,19],
            'OTT_UCHIYAMA_MONFILS_3_DUBAI_2020_HARD':[2,2,0,15],
            'OTT_TSITSIPAS_BUBLIK_3_DUBAI_2020_HARD':[1,2,1,23],
            'OTT_KOHLSCHREIBER_DJOKOVIC_3_DUBAI_2020_HARD':[2,2,0,16],
            'QRT_RUBLEV_EVANS_3_DUBAI_2020_HARD':[2,2,1,21],
            'QRT_GASQUET_MONFILS_3_DUBAI_2020_HARD':[2,2,0,18],
            'QRT_STRUFF_TSITSIPAS_3_DUBAI_2020_HARD':[2,3,0,30],
            'QRT_DJOKOVIC_KHACHANOV_3_DUBAI_2020_HARD':[1,2,0,16],
            'SF_EVANS_TSITSIPAS_3_DUBAI_2020_HARD':[2,2,0,17],
            'SF_DJOKOVIC_MONFILS_3_DUBAI_2020_HARD':[1,3,1,28],
            'F_DJOKOVIC_TSITSIPAS_3_DUBAI_2020_HARD':[1,2,0,19],

            'OTT_FRITZ_HUMBERT_3_ACAPULCO_2020_HARD':[1,2,0,17],
            'OTT_KWON_LAJOVIC_3_ACAPULCO_2020_HARD':[1,2,1,19],
            'OTT_DIMITROV_MANNARINO_3_ACAPULCO_2020_HARD':[1,3,1,34],
            'OTT_ISNER_GIRON_3_ACAPULCO_2020_HARD':[1,2,1,22],
            'OTT_ALIASSIME_EDMUND_3_ACAPULCO_2020_HARD':[2,2,0,20],
            'OTT_MARTINEZ_WAWRINKA_3_ACAPULCO_2020_HARD':[2,2,0,20],
            'OTT_PAUL_ZVEREV_3_ACAPULCO_2020_HARD':[1,2,0,19],
            'OTT_KECMANOVIC_NADAL_3_ACAPULCO_2020_HARD':[2,2,0,20],
            'QRT_FRITZ_EDMUND_3_ACAPULCO_2020_HARD':[1,2,0,19],
            'QRT_ISNER_PAUL_3_ACAPULCO_2020_HARD':[1,3,1,30],
            'QRT_WAWRINKA_DIMITROV_3_ACAPULCO_2020_HARD':[2,2,0,20],
            'QRT_KWON_NADAL_3_ACAPULCO_2020_HARD':[2,2,0,15],
            'SF_FRITZ_ISNER_3_ACAPULCO_2020_HARD':[1,3,0,29],
            'SF_DIMITROV_NADAL_3_ACAPULCO_2020_HARD':[2,2,0,17],
            'F_FRITZ_NADAL_3_ACAPULCO_2020_HARD':[2,2,0,17],

            'OTT_MURRAY_RAONIC_3_CINCINNATI_2020_HARD':[2,2,0,16],
            'OTT_FUCSOVICS_KRAJINOVIC_3_CINCINNATI_2020_HARD':[2,2,0,15],
            'OTT_BAUTISTA_KHACHANOV_3_CINCINNATI_2020_HARD':[1,3,0,27],
            'OTT_GOFFIN_STRUFF_3_CINCINNATI_2020_HARD':[2,3,0,29],
            'OTT_OPELKA_BERRETTINI_3_CINCINNATI_2020_HARD':[1,2,1,22],
            'OTT_ISNER_TSITSIPAS_3_CINCINNATI_2020_HARD':[2,2,1,26],
            'OTT_MEDVEDEV_BEDENE_3_CINCINNATI_2020_HARD':[1,2,0,18],
            'OTT_SANDGREN_DJOKOVIC_3_CINCINNATI_2020_HARD':[2,2,0,18],
            'QRT_KRAJINOVIC_RAONIC_3_CINCINNATI_2020_HARD':[2,3,1,35],
            'QRT_OPELKA_TSITSIPAS_3_CINCINNATI_2020_HARD':[4,1,0,11],
            'QRT_BAUTISTA_MEDVEDEV_3_CINCINNATI_2020_HARD':[1,3,0,26],
            'QRT_STRUFF_DJOKOVIC_3_CINCINNATI_2020_HARD':[2,2,0,16],
            'SF_RAONIC_TSITSIPAS_3_CINCINNATI_2020_HARD':[1,2,1,22],
            'SF_BAUTISTA_DJOKOVIC_3_CINCINNATI_2020_HARD':[2,3,1,33],
            'F_RAONIC_DJOKOVIC_3_CINCINNATI_2020_HARD':[2,3,0,26],

            'OTT_NORRIE_KECMANOVIC_3_SanPIETROBURGO_2020_HARD':[1,3,1,34],
            'OTT_CORIC_SAFIULLIN_3_SanPIETROBURGO_2020_HARD':[1,2,0,21],
            'OTT_BUBLIK_RAONIC_3_SanPIETROBURGO_2020_HARD':[2,2,0,17],
            'OTT_WAWRINKA_DONSKOY_3_SanPIETROBURGO_2020_HARD':[1,3,0,25],
            'OTT_KARATSEV_KHACHANOV_3_SanPIETROBURGO_2020_HARD':[2,3,0,31],
            'OTT_HUMBERT_RUBLEV_3_SanPIETROBURGO_2020_HARD':[2,3,0,32],
            'OTT_IVASHKA_SHAPOVALOV_3_SanPIETROBURGO_2020_HARD':[2,2,0,17],
            'OTT_MEDVEDEV_OPELKA_3_SanPIETROBURGO_2020_HARD':[2,3,0,30],
            'QRT_OPELKA_CORIC_3_SanPIETROBURGO_2020_HARD':[2,2,1,22],
            'QRT_KHACHANOV_RAONIC_3_SanPIETROBURGO_2020_HARD':[2,2,1,20],
            'QRT_NORRIE_RUBLEV_3_SanPIETROBURGO_2020_HARD':[2,2,0,15],
            'QRT_SHAPOVALOV_WAWRINKA_3_SanPIETROBURGO_2020_HARD':[1,2,0,22],
            'SF_CORIC_RAONIC_3_SanPIETROBURGO_2020_HARD':[1,3,0,24],
            'SF_RUBLEV_SHAPOVALOV_3_SanPIETROBURGO_2020_HARD':[1,3,0,29],
            'F_CORIC_RUBLEV_3_SanPIETROBURGO_2020_HARD':[2,2,1,23],

            'OTT_HARRIS_JOHNSON_3_COLONIA_2020_HARD':[1,2,1,26],
            'OTT_ALBOT_OTTE_3_COLONIA_2020_HARD':[1,3,0,34],
            'OTT_FOKINA_CILIC_3_COLONIA_2020_HARD':[1,3,1,30],
            'OTT_MischaZVEREV_HURKACZ_3_COLONIA_2020_HARD':[2,2,0,19],
            'OTT_NOVAK_PAIRE_3_COLONIA_2020_HARD':[1,2,0,19],
            'OTT_ALIASSIME_LAAKSONEN_3_COLONIA_2020_HARD':[1,2,0,17],
            'OTT_SIMON_BAUTISTA_3_COLONIA_2020_HARD':[2,2,1,23],
            'OTT_ZVEREV_VERDASCO_3_COLONIA_2020_HARD':[1,2,0,17],
            'QRT_NOVAK_FOKINA_3_COLONIA_2020_HARD':[2,3,0,26],
            'QRT_ALBOT_ALIASSIME_3_COLONIA_2020_HARD':[2,2,0,15],
            'QRT_HURKACZ_BAUTISTA_3_COLONIA_2020_HARD':[2,3,1,31],
            'QRT_ZVEREV_HARRIS_3_COLONIA_2020_HARD':[1,3,0,25],
            'SF_BAUTISTA_ALIASSIME_3_COLONIA_2020_HARD':[2,3,0,25],
            'SF_FOKINA_ZVEREV_3_COLONIA_2020_HARD':[2,2,1,25],
            'F_ALIASSIME_ZVEREV_3_COLONIA_2020_HARD':[2,2,0,18],

            'OTT_EVANS_TIAFOE_3_ANTWERP_2020_HARD':[1,2,1,21],
            'OTT_LOPEZ_DeMINAUR_3_ANTWERP_2020_HARD':[2,2,0,18],
            'OTT_FRITZ_HARRIS_3_ANTWERP_2020_HARD':[2,2,1,25],
            'OTT_RAONIC_NORRIE_3_ANTWERP_2020_HARD':[1,2,1,25],
            'OTT_DIMITROV_ANDUJAR_3_ANTWERP_2020_HARD':[1,3,0,29],
            'OTT_BERGS_KHACHANOV_3_ANTWERP_2020_HARD':[2,3,0,32],
            'OTT_CARRENO_HUMBERT_3_ANTWERP_2020_HARD':[2,3,0,31],
            'OTT_GIRON_GOFFIN_3_ANTWERP_2020_HARD':[1,2,0,21],
            'QRT_HUMBERT_HARRIS_3_ANTWERP_2020_HARD':[1,2,1,22],
            'QRT_DeMINAUR_GIRON_3_ANTWERP_2020_HARD':[1,2,0,15],
            'QRT_RAONIC_DIMITROV_3_ANTWERP_2020_HARD':[4,0,0,0],
            'QRT_EVANS_KHACHANOV_3_ANTWERP_2020_HARD':[1,3,1,32],
            'SF_EVANS_HUMBERT_3_ANTWERP_2020_HARD':[2,3,1,33],
            'SF_DIMITROV_DeMINAUR_3_ANTWERP_2020_HARD':[2,3,1,36],
            'F_DeMINAUR_HUMBERT_3_ANTWERP_2020_HARD':[2,2,1,20],

            'OTT_SINNER_HERBERT_3_COLONIA2_2020_HARD':[1,2,0,16],
            'OTT_JOHNSON_FOKINA_3_COLONIA2_2020_HARD':[2,2,1,22],
            'OTT_MANNARINO_KECMANOVIC_3_COLONIA2_2020_HARD':[1,2,0,18],
            'OTT_STRUFF_NISHIOKA_3_COLONIA2_2020_HARD':[2,3,1,30],
            'OTT_ALIASSIME_GERASIMOV_3_COLONIA2_2020_HARD':[1,3,1,36],
            'OTT_SHAPOVALOV_SIMON_3_COLONIA2_2020_HARD':[2,3,0,25],
            'OTT_OTTE_SCHWARTZMAN_3_COLONIA2_2020_HARD':[2,2,0,17],
            'OTT_MILLMAN_ZVEREV_3_COLONIA2_2020_HARD':[2,3,0,24],
            'QRT_SIMON_SINNER_3_COLONIA2_2020_HARD':[2,3,0,25],
            'QRT_NISHIOKA_ALIASSIME_3_COLONIA2_2020_HARD':[2,2,0,19],
            'QRT_FOKINA_SCHWARTZMAN_3_COLONIA2_2020_HARD':[2,3,1,28],
            'QRT_ZVEREV_MANNARINO_3_COLONIA2_2020_HARD':[1,3,1,33],
            'SF_SCHWARTZMAN_ALIASSIME_3_COLONIA2_2020_HARD':[1,3,0,32],
            'SF_ZVEREV_SINNER_3_COLONIA2_2020_HARD':[1,2,1,22],
            'F_SCHWARTZMAN_ZVEREV_3_COLONIA2_2020_HARD':[2,2,0,15],

            'OTT_SONEGO_HURKACZ_3_VIENNA_2020_HARD':[1,2,1,26],
            'OTT_EVANS_RODIONOV_3_VIENNA_2020_HARD':[1,2,0,21],
            'OTT_CARRENO_ANDERSON_3_VIENNA_2020_HARD':[2,2,0,19],
            'OTT_SINNER_RUBLEV_3_VIENNA_2020_HARD':[4,0,0,3],
            'OTT_MEDVEDEV_POSPISIL_3_VIENNA_2020_HARD':[1,3,0,27],
            'OTT_TSITSIPAS_DIMITROV_3_VIENNA_2020_HARD':[2,3,1,32],
            'OTT_GARIN_THIEM_3_VIENNA_2020_HARD':[2,2,0,17],
            'OTT_CORIC_DJOKOVIC_3_VIENNA_2020_HARD':[2,2,1,22],
            'QRT_DIMITROV_EVANS_3_VIENNA_2020_HARD':[2,3,1,32],
            'QRT_MEDVEDEV_ANDERSON_3_VIENNA_2020_HARD':[2,2,1,23],
            'QRT_RUBLEV_THIEM_3_VIENNA_2020_HARD':[1,2,1,21],
            'QRT_SONEGO_DJOKOVIC_3_VIENNA_2020_HARD':[1,2,0,15],
            'SF_EVANS_SONEGO_3_VIENNA_2020_HARD':[2,2,0,19],
            'SF_ANDERSON_RUBLEV_3_VIENNA_2020_HARD':[4,1,0,15],
            'F_RUBLEV_SONEGO_3_VIENNA_2020_HARD':[1,2,0,20],

            'OTT_McDONALD_SEPPI_3_NurSULTAN_2020_HARD':[1,3,0,27],
            'OTT_VESELY_GERASIMOV_3_NurSULTAN_2020_HARD':[2,3,0,29],
            'OTT_THOMPSON_RUUSUVUORI_3_NurSULTAN_2020_HARD':[2,3,0,27],
            'OTT_ALBOT_PAUL_3_NurSULTAN_2020_HARD':[2,2,0,16],
            'OTT_MILLMAN_VERDASCO_3_NurSULTAN_2020_HARD':[1,2,0,19],
            'OTT_SUGITA_MANNARINO_3_NurSULTAN_2020_HARD':[2,2,0,14],
            'OTT_TIAFOE_KECMANOVIC_3_NurSULTAN_2020_HARD':[1,2,0,21],
            'OTT_PAIRE_KUKUSHKIN_3_NurSULTAN_2020_HARD':[2,3,1,33],
            'QRT_TIAFOE_GERASIMOV_3_NurSULTAN_2020_HARD':[1,3,1,37],
            'QRT_RUUSUVUORI_KUKUSHKIN_3_NurSULTAN_2020_HARD':[1,2,0,16],
            'QRT_PAUL_MILLMAN_3_NurSULTAN_2020_HARD':[2,3,1,36],
            'QRT_MANNARINO_McDONALD_NurSULTAN_2020_HARD':[1,2,0,17],
            'SF_MILLMAN_TIAFOE_3_NurSULTAN_2020_HARD':[1,3,0,29],
            'SF_MANNARINO_RUUSUVUORI_3_NurSULTAN_2020_HARD':[1,2,0,20],
            'F_MANNARINO_MILLMAN_3_NurSULTAN_2020_HARD':[2,2,0,19] }

# %%
matches_dataset_data = pd.DataFrame( matches_dataset_dict )
matches_dataset_data = matches_dataset_data.T
matches_dataset_data.columns = ['SEGNO','SET','TIEBREAK','GAMES']
matches_dataset_data
# Out:
#                                                SEGNO  SET  TIEBREAK  GAMES
# OTT_QUIROZ_KARLOVIC_3_DELRAY_2021_HARD             1    2         0     18
# OTT_FRATANGELO_TIAFOE_3_DELRAY_2021_HARD           2    3         0     26
# OTT_MAGER_QUERREY_3_DELRAY_2021_HARD               1    2         1     20
# OTT_KORDA_PAUL_3_DELRAY_2021_HARD                  1    3         0     27
# OTT_HURKACZ_GALAN_3_DELRAY_2021_HARD               1    2         0     16
# ...                                              ...  ...       ...    ...
# QRT_PAUL_MILLMAN_3_NurSULTAN_2020_HARD             2    3         1     36
# QRT_MANNARINO_McDONALD_NurSULTAN_2020_HARD         1    2         0     17
# SF_MILLMAN_TIAFOE_3_NurSULTAN_2020_HARD            1    3         0     29
# SF_MANNARINO_RUUSUVUORI_3_NurSULTAN_2020_HARD      1    2         0     20
# F_MANNARINO_MILLMAN_3_NurSULTAN_2020_HARD          2    2         0     19
#
# [450 rows x 4 columns]

# %%
matches_dataset_data.to_excel("matches_dataset_data.xlsx")

# %%
# numero di partite 
num = len( matches_dataset_dict )
print("Il numero delle partite nel set è : ", num )
# Out:
# Il numero delle partite nel set è :  450

# %%
# numeri segni 1/2
num_1 = 0
num_2 = 0
num_3 = 0
num_4 = 0

for v in matches_dataset_data.iloc[:,0] :
    if v==1 :
        num_1 = num_1+1
    elif v==2 :
        num_2 = num_2+1
    elif v==3 :
        num_3 = num_3+1
    elif v==4 :
        num_4 = num_4+1
        
print("Il numero di partite con segno 1 è : ", num_1 )
print("Il numero di partite con segno 2 è : ", num_2 )
print("Il numero di partite con segno 3 è : ", num_3 )
print("Il numero di partite con segno 4 è : ", num_4 )
# Out:
# Il numero di partite con segno 1 è :  227
# Il numero di partite con segno 2 è :  209
# Il numero di partite con segno 3 è :  6
# Il numero di partite con segno 4 è :  8

# %%
# numeri partite da 2/3 set
set_2 = 0
set_3 = 0


for v in matches_dataset_data.iloc[:,1] :
    if v==2 :
        set_2 = set_2+1
    elif v==3 :
        set_3 = set_3+1
print("Il numero di partite da 2 set è : ", set_2 )
print("Il numero di partite da 3 set è : ", set_3 )
# Out:
# Il numero di partite da 2 set è :  284
# Il numero di partite da 3 set è :  154

# %%
# numeri partite con e senza tiebreak 
tb_no = 0
tb_si = 0


for v in matches_dataset_data.iloc[:,2] :
    if v==0 :
        tb_no = tb_no+1
    elif v==1 :
        tb_si = tb_si+1
print("Il numero di partite senza tiebreak è : ", tb_no )
print("Il numero di partite con almeno un tiebreak è : ", tb_si )
# Out:
# Il numero di partite senza tiebreak è :  277
# Il numero di partite con almeno un tiebreak è :  173
