# %%
import pandas as pd
import numpy as np 

matches_dataset_dict = {'QUIROZ_KARLOVIC_3_DELRAY_2021_HARD':[1,2,0,18],
                        'FRATANGELO_TIAFOE_3_DELRAY_2021_HARD':[2,3,0,26],
                        'MAGER_QUERREY_3_DELRAY_2021_HARD':[1,2,1,20],
                        'KORDA_PAUL_3_DELRAY_2021_HARD':[1,3,0,27],
                        'HURKACZ_GALAN_3_DELRAY_2021_HARD':[1,2,0,16],
                        'MANNARINO_NORRIE_3_DELRAY_2021_HARD':[2,2,0,20],
                        'MONTEIRO_ISNER_3_DELRAY_2021_HARD':[2,2,1,23],
                        'HARRISON_GARIN_3_DELRAY_2021_HARD':[1,2,1,21],
                        'HARRISON_MAGER_3_DELRAY_2021_HARD':[1,2,1,23],
                        'NORRIE_TIAFOE_3_DELRAY_2021_HARD':[1,3,0,25],
                        'QUIROZ_HURKACZ_3_DELRAY_2021_HARD':[2,2,0,20],
                        'ISNER_KORDA_3_DELRAY_2021_HARD':[2,3,0,28],
                        'NORRIE_KORDA_3_DELRAY_2021_HARD':[2,2,0,21],
                        'HURKACZ_HARRISON_3_DELRAY_2021_HARD':[1,2,1,23],
                        'HURKACZ_KORDA_3_DELRAY_2021_HARD':[1,2,0,18],
                        'TRAVAGLIA_RUUSUVUORI_3_ANTALYA_2021_HARD':[1,2,1,22],
                        'LAMASINE_BUBLIK_3_ANTALYA_2021_HARD':[2,2,0,18],
                        'CELIKBILEK_BASILASHVILI_3_ANTALYA_2021_HARD':[2,2,1,23],
                        'STRUFF_GRENIER_3_ANTALYA_2021_HARD':[3,0,0,0],
                        'DeMINAUR_ANDREEV_3_ANTALYA_2021_HARD':[1,2,0,16],
                        'FOGNINI_CHARDY_3_ANTALYA_2021_HARD':[2,3,1,39],
                        'GOFFIN_KUHN_3_ANTALYA_2021_HARD':[1,2,0,14],
                        'BERRETTINI_KUZMANOV_3_ANTALYA_2021_HARD':[1,2,0,17],
                        'STRUFF_CHARDY_3_ANTALYA_2021_HARD':[2,3,1,31],
                        'BASILASHVILI_DeMINAUR_3_ANTALYA_2021_HARD':[2,2,0,18],
                        'GOFFIN_TRAVAGLIA_3_ANTALYA_2021_HARD':[1,2,0,17],
                        'BUBLIK_BERRETTINI_3_ANTALYA_2021_HARD':[1,2,1,23],
                        'BUBLIK_CHARDY_3_ANTALYA_2021_HARD':[1,3,1,32],
                        'GOFFIN_DeMINAUR_3_ANTALYA_2021_HARD':[2,3,0,27],
                        'BUBLIK_DeMINAUR_3_ANTALYA_2021_HARD':[4,0,0,2],
            'MONTEIRO_ALCARAZ_3_GreatOCEAN_2021_HARD':[1,2,1,22],
            'THOMPSON_VilellaMARTINEZ_3_GreatOCEAN_2021_HARD':[1,2,0,20],
            'BUBLIK_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[2,2,0,19],
            'CARUSO_KECMANOVIC_3_GreatOCEAN_2021_HARD':[2,3,1,37],
            'VandeZANDSCHULP_OPELKA_3_GreatOCEAN_2021_HARD':[1,2,1,26],
            'BEDENE_SINNER_3_GreatOCEAN_2021_HARD':[2,2,1,21],
            'CUEVAS_HURKACZ_3_GreatOCEAN_2021_HARD':[2,2,0,24],
            'ANDERSON_KHACHANOV_3_GreatOCEAN_2021_HARD':[2,2,1,22],
            'MONTEIRO_THOMPSON_3_GreatOCEAN_2021_HARD':[1,2,0,20],
            'SINNER_KECMANOVIC_3_GreatOCEAN_2021_HARD':[1,2,1,23],
            'HURKACZ_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[2,3,0,30],
            'KHACHANOV_VandeZANDSCHULP_3_GreatOCEAN_2021_HARD':[1,3,1,34],
            'TRAVAGLIA_MONTEIRO_3_GreatOCEAN_2021_HARD':[1,2,0,19],
            'KHACHANOV_SINNER_3_GreatOCEAN_2021_HARD':[2,3,1,36],
            'SINNER_TRAVAGLIA_3_GreatOCEAN_2021_HARD':[1,2,1,23],
            'VESELY_BERANKIS_3_MurrayRIVER_2021_HARD':[1,2,0,18],
            'DUCKWORTH_MOUTET_3_MurrayRIVER_2021_HARD':[2,2,1,23],
            'GIRON_EVANS_3_MurrayRIVER_2021_HARD':[2,2,1,23],
            'FRITZ_CHARDY_3_MurrayRIVER_2021_HARD':[2,2,0,18],
            'CORIC_KYRGIOS_3_MurrayRIVER_2021_HARD':[1,2,0,19],
            'GERASIMOV_ALIASSIME_3_RiverMURRAY_2021_HARD':[2,3,1,31],
            'DIMITROV_POPYRIN_3_RiverMURRAY_2021_HARD':[1,3,1,32],
            'BOLT_WAWRINKA_3_RiverMURRAY_2021_HARD':[2,3,1,33],
            'EVANS_CORIC_3_RiverMURRAY_2021_HARD':[1,2,1,25],
            'ALIASSIME_VESELY_3_RiverMURRAY_2021_HARD':[3,1,1,13],
            'DIMITROV_MOUTET_3_MurrayRIVER_2021_HARD':[2,2,0,20],
            'WAWRINKA_CHARDY_3_MurrayRIVER_2021_HARD':[4,0,0,0],
            'EVANS_CHARDY_3_MurrayRIVER_2021_HARD':[1,2,0,16],
            'MOUTET_ALIASSIME_3_MurrayRIVER_2021_HARD':[2,2,0,15],
            'ALIASSIME_EVANS_3_MurrayRIVER_2021_HARD':[2,2,0,17],
            'ANDREEV_POPYRIN_3_SINGAPORE_2021_HARD':[2,3,0,28],
            'UCHIYAMA_KWON_3_SINGAPORE_2021_HARD':[2,2,0,19],
            'ALBOT_HANFMANN_3_SINGAPORE_2021_HARD':[1,3,1,35],
            'CRESSY_NISHIOKA_3_SINGAPORE_2021_HARD':[2,2,0,18],
            'BUBLIK_CELIKBILEK_3_SINGAPORE_2021_HARD':[1,2,0,16],
            'DANIEL_CILIC_3_SINGAPORE_2021_HARD':[2,2,0,22],
            'EBDEN_MILLMAN_3_SINGAPORE_2021_HARD':[1,2,0,17],
            'MANNARINO_MARCORA_3_SINGAPORE_2021_HARD':[1,2,0,21],
            'POPYRIN_EBDEN_3_SINGAPORE_2021_HARD':[1,2,1,23],
            'NISHIOKA_BUBLIK_3_SINGAPORE_2021_HARD':[2,2,0,17],
            'CILIC_KWON_3_SINGAPORE_2021_HARD':[1,3,0,28],
            'MANNARINO_ALBOT_3_SINGAPORE_2021_HARD':[2,2,0,19],
            'BUBLIK_ALBOT_3_SINGAPORE_2021_HARD':[1,3,0,27],
            'CILIC_POPYRIN_3_SINGAPORE_2021_HARD':[2,2,1,26],
            'POPYRIN_BUBLIK_3_SINGAPORE_2021_HARD':[1,3,0,24],
            'GOJOWCZYK_VESELY_3_MONTPELLER_2021_HARD':[1,3,1,35],
            'GERASIMOV_BEDENE_3_MONTPELLIER_2021_HARD':[1,2,1,23],
            'SONEGO_KORDA_3_MONTPELLIER_2021_HARD':[1,2,0,17],
            'GRIEKSPOOR_HUMBERT_3_MONTPELLIER_2021_HARD':[2,3,1,39],
            'FOKINA_HURKACZ_3_MONTPELLIER_2021_HARD':[1,2,0,20],
            'LAJOVIC_NOVAK_3_MONTPELLIER_2021_HARD':[2,2,1,25],
            'BONZI_GOFFIN_3_MONTPELLIER_2021_HARD':[2,3,0,32],
            'BAUTISTA_BARRERE_3_MONTPELLIER_2021_HARD':[1,2,0,15],
            'GOJOWCZYK_NOVAK_3_MONTPELLIER_2021_HARD':[1,2,0,17],
            'FOKINA_GERASIMOV_3_MONTPELLIER_2021_HARD':[2,3,0,32],
            'GOFFIN_SONEGO_3_MONTPELLIER_2021_HARD':[1,2,0,20],
            'BAUTISTA_HUMBERT_3_MONTPELLIER_2021_HARD':[1,2,0,18],
            'GERASIMOV_GOFFIN_3_MONTPELLIER_2021_HARD':[2,3,0,28],
            'GOJOWCZYK_BAUTISTA_3_MONTPELLIER_2021_HARD':[2,2,0,19],
            'GOFFIN_BAUTISTA_3_MONTPELLIER_2021_HARD':[1,3,0,30],
            'PAUL_BUBLIK_3_ROTTERDAM_2021_HARD':[1,3,1,29],
            'NISHIKORI_DeMINAUR_3_ROTTERDAM_2021_HARD':[1,3,0,29],
            'NORRIE_KHACHANOV_3_ROTTERDAM_2021_HARD':[2,2,0,16],
            'FOKINA_FUCSOVICS_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'LAJOVIC_CORIC_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'CHARDY_GOFFIN_3_ROTTERDAM_2021_HARD':[1,2,1,26],
            'MURRAY_RUBLEV_3_ROTTERDAM_2021_HARD':[2,2,0,20],
            'TSITSIPAS_HURKACZ_3_ROTTERDAM_2021_HARD':[1,3,0,32],
            'FUCSOVICS_PAUL_3_ROTTERDAM_2021_HARD':[1,2,0,19],
            'NISHIKORI_CORIC_3_ROTTERDAM_2021_HARD':[2,2,1,26],
            'RUBLEV_CHARDY_3_ROTTERDAM_2021_HARD':[1,3,1,36],
            'TSITSIPAS_KHACHANOV_3_ROTTERDAM_2021_HARD':[1,3,0,31],
            'CORIC_FUCSOVICS_3_ROTTERDAM_2021_HARD':[2,2,0,17],
            'RUBLEV_TSITSIPAS_ROTTERDAM_2021_HARD':[1,2,1,22],
            'FUCSOVICS_RUBLEV_3_ROTTERDAM_2021_HARD':[2,2,1,23],
            'HARRIS_FUCSOVICS_3_DOHA_2021_HARD':[2,3,1,31],
            'BASILASHVILI_JAZIRI_3_DOHA_2021_HARD':[1,2,0,16],
            'GOFFIN_FRITZ_3_DOHA_2021_HARD':[2,3,1,32],
            'BAUTISTA_BUBLIK_3_DOHA_2021_HARD':[1,2,0,19],
            'SHAPOVALOV_POSPISIL_3_DOHA_2021_HARD':[1,2,0,22],
            'GASQUET_RUBLEV_3_DOHA_2021_HARD':[4,0,0,0],
            'FEDERER_EVANS_3_DOHA_2021_HARD':[1,3,1,34],
            'THIEM_KARATSEV_3_DOHA_2021_HARD':[1,3,1,30],
            'SHAPOVALOV_FRITZ_3_DOHA_2021_HARD':[2,3,0,33],
            'RUBLEV_FUCSOVICS_3_DOHA_2021_HARD':[3,0,0,0],
            'BASILASHVILI_FEDERER_3_DOHA_2021_HARD':[1,3,0,28],
            'BAUTISTA_THIEM_3_DOHA_2021_HARD':[1,3,1,31],
            'FRITZ_BASILASHVILI_3_DOHA_2021_HARD':[2,2,1,20],
            'BAUTISTA_RUBLEV_3_DOHA_2021_HARD':[1,2,0,18],
            'BAUTISTA_BASILASHVILI_3_DOHA_2021_HARD':[2,2,1,21],
            'HERBERT_NORRIE_3_MARSIGLIA_2021_HARD':[1,2,0,19],
            'RUUSUVUORI_EBDEN_3_MARSIGLIA_2021_HARD':[2,2,0,16],
            'FOKINA_RINDERKNECH_3_MARSIGLIA_2021_HARD':[2,3,0,24],
            'SINNER_GASTON_3_MARSIGLIA_2021_HARD':[1,2,0,17],
            'HUMBERT_TSONGA_3_MARSIGLIA_2021_HARD':[1,2,0,19],
            'KHACHANOV_McDONALD_3_MARSIGLIA_2021_HARD':[1,2,1,23],
            'POUILLE_TSITSIPAS_3_MARSIGLIA_2021_HARD':[2,2,0,17],
            'MEDVEDEV_GERASIMOV_3_MARSIGLIA_2021_HARD':[1,2,0,18],
            'RINDERKNECH_HUMBERT_3_MARSIGLIA_2021_HARD':[2,3,1,35],
            'EBDEN_KHACHANOV_3_MARSIGLIA_2021_HARD':[1,3,0,28],
            'HERBERT_TSITSIPAS_3_MARSIGLIA_2021_HARD':[1,3,1,31],
            'SINNER_MEDVEDEV_3_MARSIGLIA_2021_HARD':[2,2,0,18],
            'HERBERT_HUMBERT_3_MARSIGLIA_2021_HARD':[1,2,0,17],
            'MEDVEDEV_EBDEN_3_MARSIGLIA_2021_HARD':[3,2,0,13],
            'MEDVEDEV_HERBERT_3_MARSIGLIA_2021_HARD':[1,3,1,33],
            'NISHIKORI_BEDENE_3_DUBAI_2021_HARD':[1,2,0,20],
            'SONEGO_KARATSEV_3_DUBAI_2021_HARD':[2,3,0,28],
            'KRAJINOVIC_HARRIS_3_DUBAI_2021_HARD':[2,2,1,23],
            'FUCSOVICS_LAJOVIC_3_DUBAI_2021_HARD':[1,3,0,27],
            'CHARDY_KHACHANOV_3_DUBAI_2021_HARD':[1,3,1,33],
            'BAUTISTA_SINNER_3_DUBAI_2021_HARD':[2,3,0,31],
            'SHAPOVALOV_HURKACZ_3_DUBAI_2021_HARD':[1,2,0,19],
            'RUBLEV_FRITZ_3_DUBAI_2021_HARD':[1,2,0,16],
            'HARRIS_NISHIKORI_3_DUBAI_2021_HARD':[1,3,0,25],
            'KARATSEV_SINNER_3_DUBAI_2021_HARD':[1,3,1,30],
            'CHARDY_SHAPOVALOV_3_DUBAI_2021_HARD':[2,2,0,22],
            'RUBLEV_FUCSOVICS_3_DUBAI_2021_HARD':[1,2,0,20],
            'HARRIS_SHAPOVALOV_3_DUBAI_2021_HARD':[1,3,1,36],
            'RUBLEV_KARATSEV_3_DUBAI_2021_HARD':[2,3,0,28],
            'KARATSEV_HARRIS_3_DUBAI_2021_HARD':[1,2,0,17],
                        
            'OTT_MUSETTI_TIAFOE_3_ACAPULCO_2021_HARD':[1,3,1,30],
            'OTT_GRIEKSPOOR_RUUD_3_ACAPULCO_2021_HARD':[2,3,1,32],
            'OTT_ALIASSIME_KORDA_3_ACAPULCO_2021_HARD':[1,2,0,19],
            'OTT_NORRIE_FOGNINI_3_ACAPULCO_2021_HARD':[1,2,0,19],
            'OTT_DIMITROV_KECMANOVIC_3_ACAPULCO_2021_HARD':[1,2,0,18],
            'OTT_RAONIC_KOEPFER_3_ACAPULCO_2021_HARD':[2,2,0,18],
            'OTT_DJERE_ZVEREV_3_ACAPULCO_2021_HARD':[2,2,0,19],
            'OTT_TSITSIPAS_ISNER_3_ACAPULCO_2021_HARD':[1,2,0,17],
            'QRT_KOEPFER_NORRIE_3_ACAPULCO_2021_HARD':[1,2,0,22],
            'QRT_MUSETTI_DIMITROV_3_ACAPULCO_2021_HARD':[1,2,1,23],
            'QRT_ZVEREV_RUUD_3_ACAPULCO_2021_HARD':[3,0,0,0],
            'QRT_TSITSIPAS_ALIASSIME_3_ACAPULCO_2021_HARD':[1,3,0,31],
            'SF_KOEPFER_ZVEREV_3_ACAPULCO_2021_HARD':[2,2,1,23],
            'SF_MUSETTI_TSITSIPAS_3_ACAPULCO_2021_HARD':[2,2,0,16],
            'F_ZVEREV_TSITSIPAS_3_ACAPULCO_2021_HARD':[1,2,1,23],
                        
            'OTT_FRITZ_BUBLIK_3_MIAMI_2021_HARD':[2,3,1,32],
            'OTT_RUUSUVUORI_SINNER_3_MIAMI_2021_HARD':[2,2,0,17],
            'OTT_HURKACZ_RAONIC_3_MIAMI_2021_HARD':[1,3,1,32],
            'OTT_BAUTISTA_ISNER_3_MIAMI_2021_HARD':[1,3,1,32],
            'OTT_SCHWARTZMAN_KORDA_3_MIAMI_2021_HARD':[2,3,0,31],
            'OTT_RUBLEV_CILIC_3_MIAMI_2021_HARD':[1,2,0,20],
            'OTT_SONEGO_TSITSIPAS_3_MIAMI_2021_HARD':[2,2,1,21],
            'OTT_TIAFOE_MEDVEDEV_3_MIAMI_2021_HARD':[2,2,0,19],
            'QRT_SINNER_BUBLIK_3_MIAMI_2021_HARD':[1,2,1,23],
            'QRT_KORDA_RUBLEV_3_MIAMI_2021_HARD':[2,2,1,25],
            'QRT_HURKACZ_TSITSIPAS_3_MIAMI_2021_HARD':[1,3,0,27],
            'QRT_BAUTISTA_MEDVEDEV_3_MIAMI_2021_HARD':[1,2,0,18],
            'SF_BAUTISTA_SINNER_3_MIAMI_2021_HARD':[2,3,0,32],
            'SF_HURKACZ_RUBLEV_3_MIAMI_2021_HARD':[1,2,0,19],
            'F_HURKACZ_SINNER_3_MIAMI_2021_HARD':[1,2,1,23],
                        
            'OTT_FUCSOVICS_ILKEL_3_DOHA_2020_HARD':[1,2,0,17],
            'OTT_BUBLIK_BEDENE_3_DOHA_2020_HARD':[2,2,0,21],
            'OTT_KRAJINOVIC_VERDASCO_3_DOHA_2020_HARD':[2,3,0,28],
            'OTT_DJERE_HERBERT_3_DOHA_2020_HARD':[2,2,0,16],
            'OTT_MOUTET_RAONIC_3_DOHA_2020_HARD':[1,2,1,26],
            'OTT_TSONGA_KECMANOVIC_3_DOHA_2020_HARD':[2,2,1,20],
            'OTT_RUBLEV_KUKUSHKIN_3_DOHA_2020_HARD':[1,2,0,18],
            'OTT_CHARDY_WAWRINKA_3_DOHA_2020_HARD':[2,2,0,19],
            'QRT_MOUTET_VERDASCO_3_DOHA_2020_HARD':[1,3,0,30],
            'QRT_FUCSOVICS_KECMANOVIC_3_DOHA_2020_HARD':[2,2,0,14],
            'QRT_HERBERT_RUBLEV_3_DOHA_2020_HARD':[2,2,0,19],
            'QRT_WAWRINKA_BEDENE_3_DOHA_2020_HARD':[1,2,0,19],
            'SF_RUBLEV_KECMANOVIC_3_DOHA_2020_HARD':[1,2,0,16],
            'SF_MOUTET_WAWRINKA_3_DOHA_2020_HARD':[1,3,0,30],
            'F_MOUTET_RUBLEV_3_DOHA_2020_HARD':[2,2,1,21],
                       
            'OTT_VINOLAS_MUNAR_3_ADELAIDE_2020_HARD':[1,2,1,22],
            'OTT_CUEVAS_PAUL_3_ADELAIDE_2020_HARD':[2,2,0,15],
            'OTT_DJERE_HARRIS_3_ADELAIDE_2020_HARD':[2,2,1,22],
            'OTT_EVANS_BUBLIK_3_ADELAIDE_2020_HARD':[1,2,0,20],
            'OTT_BOLT_STRUFF_3_ADELAIDE_2020_HARD':[1,2,0,19],
            'OTT_CARRENO_CHARDY_3_ADELAIDE_2020_HARD':[1,2,0,17],
            'OTT_QUERREY_RUBLEV_3_ADELAIDE_2020_HARD':[2,2,0,18],
            'OTT_DUCKWORTH_ALIASSIME_3_ADELAIDE_2020_HARD':[2,2,1,22],
            'QRT_PAUL_VINOLAS_3_ADELAIDE_2020_HARD':[1,2,0,19],
            'QRT_CARRENO_HARRIS_3_ADELAIDE_2020_HARD':[2,2,0,18],
            'QRT_EVANS_RUBLEV_3_ADELAIDE_2020_HARD':[2,3,0,28],
            'QRT_BOLT_ALIASSIME_3_ADELAIDE_2020_HARD':[2,2,0,15],
            'SF_HARRIS_PAUL_3_ADELAIDE_2020_HARD':[1,3,1,32],
            'SF_RUBLEV_ALIASSIME_3_ADELAIDE_2020_HARD':[1,3,1,36],
            'F_HARRIS_RUBLEV_3_ADELAIDE_2020_HARD':[2,2,0,15],
                       
            'OTT_CECCHINATO_HUMBERT_3_AUCKLAND_2020_HARD':[2,2,0,17],
            'OTT_SEPPI_EDMUND_3_AUCKLAND_2020_HARD':[2,2,1,22],
            'OTT_YMER_HURKACZ_3_AUCKLAND_2020_HARD':[2,2,1,21],
            'OTT_MONTEIRO_PAIRE_3_AUCKLAND_2020_HARD':[2,3,0,29],
            'OTT_ISNER_SANDGREN_3_AUCKLAND_2020_HARD':[1,3,1,35],
            'OTT_KHACHANOV_MILLMAN_3_AUCKLAND_2020_HARD':[2,3,0,28],
            'OTT_SHAPOVALOV_POSPISIL_3_AUCKLAND_2020_HARD':[1,2,1,23],
            'OTT_LOPEZ_FOGNINI_3_AUCKLAND_2020_HARD':[1,3,0,28],
            'QRT_LOPEZ_HURKACZ_3_AUCKLAND_2020_HARD':[2,3,1,33],
            'QRT_MILLMAN_PAIRE_3_AUCKLAND_2020_HARD':[2,3,0,26],
            'QRT_EDMUND_ISNER_3_AUCKLAND_2020_HARD':[2,2,1,26],
            'QRT_HUMBERT_SHAPOVALOV_3_AUCKLAND_2020_HARD':[1,2,0,22],
            'SF_HURKACZ_PAIRE_3_AUCKLAND_2020_HARD':[2,3,1,31],
            'SF_HUMBERT_ISNER_3_AUCKLAND_2020_HARD':[1,2,1,23],
            'F_PAIRE_HUMBERT_3_AUCKLAND_2020_HARD':[2,3,1,35]}

# %%
matches_dataset_data = pd.DataFrame( matches_dataset_dict )
matches_dataset_data = matches_dataset_data.T
matches_dataset_data.columns = ['SEGNO','SET','TIEBREAK','GAMES']
matches_dataset_data
# Out:
#                                              SEGNO  SET  TIEBREAK  GAMES
# QUIROZ_KARLOVIC_3_DELRAY_2021_HARD               1    2         0     18
# FRATANGELO_TIAFOE_3_DELRAY_2021_HARD             2    3         0     26
# MAGER_QUERREY_3_DELRAY_2021_HARD                 1    2         1     20
# KORDA_PAUL_3_DELRAY_2021_HARD                    1    3         0     27
# HURKACZ_GALAN_3_DELRAY_2021_HARD                 1    2         0     16
# ...                                            ...  ...       ...    ...
# QRT_EDMUND_ISNER_3_AUCKLAND_2020_HARD            2    2         1     26
# QRT_HUMBERT_SHAPOVALOV_3_AUCKLAND_2020_HARD      1    2         0     22
# SF_HURKACZ_PAIRE_3_AUCKLAND_2020_HARD            2    3         1     31
# SF_HUMBERT_ISNER_3_AUCKLAND_2020_HARD            1    2         1     23
# F_PAIRE_HUMBERT_3_AUCKLAND_2020_HARD             2    3         1     35
#
# [225 rows x 4 columns]

# %%
matches_dataset_data.to_excel("matches_dataset_data.xlsx")

# %%
# numero di partite 
num = len( matches_dataset_dict )
print("Il numero delle partite nel set è : ", num )
# Out:
# Il numero delle partite nel set è :  225

# %%
# numeri segni 1/2
num_1 = 0
num_2 = 0
num_3 = 0
num_4 = 0

for v in matches_dataset_data.iloc[:,0] :
    if v==1 :
        num_1 = num_1+1
    elif v==2 :
        num_2 = num_2+1
    elif v==3 :
        num_3 = num_3+1
    elif v==4 :
        num_4 = num_4+1
        
print("Il numero di partite con segno 1 è : ", num_1 )
print("Il numero di partite con segno 2 è : ", num_2 )
print("Il numero di partite con segno 3 è : ", num_3 )
print("Il numero di partite con segno 4 è : ", num_4 )
# Out:
# Il numero di partite con segno 1 è :  117
# Il numero di partite con segno 2 è :  100
# Il numero di partite con segno 3 è :  5
# Il numero di partite con segno 4 è :  3

# %%
# numeri partite da 2/3 set
set_2 = 0
set_3 = 0


for v in matches_dataset_data.iloc[:,1] :
    if v==2 :
        set_2 = set_2+1
    elif v==3 :
        set_3 = set_3+1
print("Il numero di partite da 2 set è : ", set_2 )
print("Il numero di partite da 3 set è : ", set_3 )
# Out:
# Il numero di partite da 2 set è :  144
# Il numero di partite da 3 set è :  74

# %%
# numeri partite con e senza tiebreak 
tb_no = 0
tb_si = 0


for v in matches_dataset_data.iloc[:,2] :
    if v==0 :
        tb_no = tb_no+1
    elif v==1 :
        tb_si = tb_si+1
print("Il numero di partite senza tiebreak è : ", tb_no )
print("Il numero di partite con almeno un tiebreak è : ", tb_si )
# Out:
# Il numero di partite senza tiebreak è :  141
# Il numero di partite con almeno un tiebreak è :  84
