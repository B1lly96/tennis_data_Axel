# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(64) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 64
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

US_OPEN_placement_dict = {'2021':lista_NaN,
    
                          '2020':['THIEM','ZVEREV','MEDVEDEV','CARRENO',
                                          'DeMINAUR','RUBLEV','CORIC','SHAPOVALOV',
                          'DJOKOVIC','ALIASSIME','TIAFOE','FOKINA','BERRETTINI','GOFFIN','POSPISIL','THOMPSON',
                          'STRUFF','CILIC','WOLF','TSITSIPAS','MANNARINO','RUUD','KRAJINOVIC','BAUTISTA',
                          'CARUSO','KHACHANOV','FRITZ','MOUTET','BERANKIS','NORRIE','KUKUSHKIN','FUCSOVICS',
                          'EDMUND','NAGAL','OCONNELL','CRESSY','NAKASHIMA','HUMBERT','HARRIS','KECMANOVIC',
                          'BARRERE','KUZNETSOV','KWON','GARIN','DIMITROV','MURRAY','SIMON','KRUEGER',
                          'GASQUET','EVANS','HURKACZ','RAONIC','GIRON','LONDERO','MMOH','RUUSUVUORI',
                          'GOMBOS','SOCK','JOHNSON','ESCOBEDO','CORIA','GERASIMOV','MILLMAN','CarballesBAENA'],
                         
                          '2019':['NADAL','MEDVEDEV','BERRETTINI','DIMITROV',
                                           'SCHWARTZMAN','FEDERER','WAWRINKA','MONFILS',
                          'DJOKOVIC','CILIC','GOFFIN','KOEPFER','ZVEREV','ANDUJAR','RUBLEV','DeMINAUR',
                          'KUDLA','CHUNG','EVANS','LOPEZ','BEDENE','NISHIKORI','SHAPOVALOV','ISNER',
                          'CARRENO','BASILASHVILI','SANDGREN','LORENZI','POPYRIN','KYRGIOS','BUBLIK','MAJCHRZAK',
                          'LONDERO','KOKKINAKIS','DZUMHUR','DELLIEN','TIAFOE','KLAHN','CORIC','COPIL',
                          'STRUFF','BARRERE','BROOKSBY','GERASIMOV','STEBE','CHARDY','THOMPSON','POUILLE',
                          'LAJOVIC','HOANG','PAIRE','GARIN','VERDASCO','SONEGO','FABBIANO','BERANKIS',
                          'OPELKA','NISHIOKA','KECMANOVIC','CUEVAS','KUKUSHKIN','SIMON','POSPISIL','LAAKSONEN'],
                         
                          '2018':['DJOKOVIC','DelPOTRO','NADAL','NISHIKORI',
                                  'THIEM','ISNER','MILLMAN','CILIC',
                          'BASILASHVILI','FEDERER','CORIC','ANDERSON','SOUSA','GOFFIN','RAONIC','KOHLSCHREIBER',
                          'KHACHANOV','KYRGIOS','VERDASCO','ZVEREV','SHAPOVALOV','GASQUET','DeMINAUR','FRITZ',
                          'STRUFF','LAJOVIC','SCHWARTZMAN','POUILLE','MEDVEDEV','WAWRINKA','PELLA','KUKUSHKIN',
                          'POSPISIL','PAIRE','KUDLA','MAHUT','CHARDY','SANDGREN','HURKACZ','JOHNSON',
                          'HAASE','JARRY','CARRENO','MUNAR','FOGNINI','TSITSIPAS','BAGHDATIS','SOCK',
                          'CarballesBAENA','MONFILS','CHUNG','SIMON','DJERE','SONEGO','SEPPI','HERBERT',
                          'MURRAY','TIAFOE','KUBLER','EBDEN','NORRIE','LORENZI','BENNETEAU','HUMBERT'],
                         
                          '2017':['NADAL','ANDERSON','DelPOTRO','CARRENO',
                                  'RUBLEV','FEDERER','SCHWARTZMAN','QUERREY',
                          'DOLGOPOLOV','KOHLSCHREIBER','THIEM','GOFFIN','SHAPOVALOV','POUILLE','MischaZVEREV','LORENZI',
                          'MAYER','LOPEZ','CILIC','MANNARINO','MONFILS','ISNER','BAUTISTA','MAHUT',
                          'KUKUSHKIN','ALBOT','CORIC','MILLMAN','TROICKI','FABBIANO','DZUMHUR','EDMUND',
                          'DANIEL','YOUZHNY','ZVEREV','FlorianMAYER','FRITZ','DIMITROV','TSONGA','PELLA',
                          'CHUNG','BROWN','NORRIE','BERDYCH','DONALDSON','SELA','YOUNG','MULLER',
                          'VINOLAS','PAIRE','MenendezMACEIRAS','GULBIS','TIPSAREVIC','FRATANGELO','VERDASCO','GIRALDO',
                          'LU','STEBE','JOHNSON','THOMPSON','DONSKOY','SUGITA','JAZIRI','TRAVAGLIA'],
                         
                          '2016':['WAWRINKA','DJOKOVIC','MONFILS','NISHIKORI',
                                  'TSONGA','MURRAY','DelPOTRO','POUILLE',
                          'EDMUND','DIMITROV','MARCHENKO','NADAL','KARLOVIC','THIEM','SOCK','BAGHDATIS',
                          'YOUZHNY','LORENZI','EVANS','KUZNETSOV','MAHUT','CILIC','CARRENO','ANDERSON',
                          'ALMAGRO','FERRER','KYRGIOS','BAUTISTA','ISNER','DONALDSON','SOUSA','HARRISON',
                          'VESELY','GRANOLLERS','GIANNESSI','SEPPI','RAONIC','KHACHANOV','STAKHOVSKY','BERANKIS',
                          'DUCKWORTH','SATRAL','FOGNINI','ZEBALLOS','DelBONIS','LOPEZ','CUEVAS','JOHNSON',
                          'DARCIS','YOUNG','CHARDY','POSPISIL','CHIUDINELLI','MischaZVEREV','ZVEREV','SIMON',
                          'VINOLAS','PAIRE','TIPSAREVIC','TROICKI','ESCOBEDO','MATHIEU','DZUMHUR','PELLA'],
                         
                          '2015':['DJOKOVIC','FEDERER','CILIC','WAWRINKA',
                                  'LOPEZ','GASQUET','ANDERSON','TSONGA',
                          'BAUTISTA','ISNER','MURRAY','YOUNG','BERDYCH','CHARDY','FOGNINI','PAIRE',
                          'SEPPI','KOHLSCHREIBER','BELLUCCI','BEMELMANS','GARCIA','FERRER','NADAL','KUKUSHKIN',
                          'RAONIC','TOMIC','VESELY','GOFFIN','THIEM','STAKHOVSKY','TROICKI','ROBREDO',
                          'HaiderMAURER','DARCIS','MANNARINO','CHUNG','MELZER','KRAJINOVIC','SCHWARTZMAN','DONSKOY',
                          'VERDASCO','HAASE','YOUZHNY','BERANKIS','KRAJICEK','DIMITROV','FISH','GRANOLLERS',
                          'ISTOMIN','KARLOVIC','RAM','CARRENO','HEWITT','GABASHVILI','GROTH','KLIZAN',
                          'SOCK','ROSOL','NISHIOKA','MAHUT','CUEVAS','ILHAN','MARCHENKO','BEDENE'],
                         
                          '2014':['CILIC','NISHIKORI','DJOKOVIC','FEDERER',
                                  'MURRAY','MONFILS','WAWRINKA','BERDYCH',
                          'KOHLSCHREIBER','BAUTISTA','ROBREDO','RAONIC','THIEM','DIMITROV','TSONGA','SIMON',
                          'QUERREY','GRANOLLERS','KAVCIC','FERRER','EstrellaBURGOS','GABASHVILI','GOFFIN','KUZNETSOV',
                          'CARRENO','MAYER','GASQUET','ISNER','ANDERSON','KYRGIOS','MANNARINO','LOPEZ',
                          'MATHIEU','GROTH','BELLUCCI','TOMIC','GOJOWCZYK','KLIZAN','SELA','BACHINGER',
                          'NEDOVYESOV','ANDUJAR','GULBIS','LORENZI','STRUFF','MARCHENKO','FOGNINI','BOLELLI',
                          'SMYCZEK','JANOWICZ','ITO','GONZALEZ','LLODRA','EBDEN','KARLOVIC','DelBONIS',
                          'GARCIA','CHARDY','VERDASCO','SOUSA','PAIRE','CORIC','KUDRYAVTSEV','SEPPI']}

# %%
US_OPEN_PLACEMENTS_DATA = pd.DataFrame( US_OPEN_placement_dict )
US_OPEN_PLACEMENTS_DATA = US_OPEN_PLACEMENTS_DATA.T
US_OPEN_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16',
                                         '64_1','64_2','64_3','64_4','64_5','64_6','64_7','64_8',
                                         '64_9','64_10','64_11','64_12','64_13','64_14','64_15','64_16',
                                         '64_17','64_18','64_19','64_20','64_21','64_22','64_23','64_24',
                                         '64_25','64_26','64_27','64_28','64_29','64_30','64_31','64_32']
US_OPEN_PLACEMENTS_DATA
# Out:
#         winner   finalist       semi1      semi2           q1       q2  \
# 2021       NaN        NaN         NaN        NaN          NaN      NaN
# 2020     THIEM     ZVEREV    MEDVEDEV    CARRENO     DeMINAUR   RUBLEV
# 2019     NADAL   MEDVEDEV  BERRETTINI   DIMITROV  SCHWARTZMAN  FEDERER
# 2018  DJOKOVIC   DelPOTRO       NADAL  NISHIKORI        THIEM    ISNER
# 2017     NADAL   ANDERSON    DelPOTRO    CARRENO       RUBLEV  FEDERER
# 2016  WAWRINKA   DJOKOVIC     MONFILS  NISHIKORI       TSONGA   MURRAY
# 2015  DJOKOVIC    FEDERER       CILIC   WAWRINKA        LOPEZ  GASQUET
# 2014     CILIC  NISHIKORI    DJOKOVIC    FEDERER       MURRAY  MONFILS
#
#                q3          q4             o1             o2  ...     64_23  \
# 2021          NaN         NaN            NaN            NaN  ...       NaN
# 2020        CORIC  SHAPOVALOV       DJOKOVIC      ALIASSIME  ...      MMOH
# 2019     WAWRINKA     MONFILS       DJOKOVIC          CILIC  ...  FABBIANO
# ...

# %%
US_OPEN_PLACEMENTS_DATA.to_excel("US_OPEN_PLACEMENTS_DATA.xlsx")
