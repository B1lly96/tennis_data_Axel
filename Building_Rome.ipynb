# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Rome_placements_dict = {'2014':['DJOKOVIC','NADAL','DIMITROV','RAONIC',
                                'MURRAY','FERRER','CHARDY','HAAS',
                        'YOUZHNY','KOHLSCHREIBER','WAWRINKA','GULBIS','BERDYCH','MELZER','TSONGA','DODIG',
                        'SIMON','STEPANEK','RIBA','FEDERER','KUKUSHKIN','TURSUNOV','GRANOLLERS','BOLELLI',
                        'ANDERSON','KARLOVIC','GOLUBEV','SIJSLING','ROBREDO','ROSOL','ROBERT','CILIC'],
                       
                        '2015':['DJOKOVIC','FEDERER','FERRER','WAWRINKA',
                                'NISHIKORI','BERDYCH','NADAL','GOFFIN',
                        'BELLUCCI','ANDERSON','MURRAY','ISNER','TROICKI','FOGNINI','GARCIA','THIEM',
                        'ALMAGRO','CUEVAS','CHARDY','ILHAN','VESELY','DONATI','GASQUET','MONACO',
                        'DIMITROV','LOPEZ','SIMON','TSONGA','BAUTISTA','KOHLSCHREIBER','MAYER','DOLGOPOLOV'],
                       
                        '2016':['MURRAY','DJOKOVIC','NISHIKORI','POUILLE',
                                'NADAL','GOFFIN','THIEM','MONACO',
                        'BELLUCCI','CHARDY','FEDERER','WAWRINKA','KYRGIOS','GASQUET','BERDYCH','FERRER',
                        'ROBERT','KUKUSHKIN','ZVEREV','PAIRE','KOHLSCHREIBER','TROICKI','VINOLAS','GARCIA',
                        'RAONIC','SEPPI','SOCK','SOUSA','BAUTISTA','ANDERSON','MAHUT','GULBIS'],
                       
                        '2017':['ZVEREV','DJOKOVIC','THIEM','ISNER',
                                'DelPOTRO','NADAL','RAONIC','CILIC',
                        'BAUTISTA','WAWRINKA','SOCK','BERDYCH','GOFFIN','NISHIKORI','QUERREY','FOGNINI',
                        'MURRAY','BEDENE','PAIRE','ALMAGRO','HAAS','HARRISON','FERRER','CUEVAS',
                        'VERDASCO','BERLOCQ','VESELY','CARRENO','TROICKI','EDMUND','FlorianMAYER','STRUFF'],
                       
                        '2018':['NADAL','ZVEREV','DJOKOVIC','CILIC',
                                'FOGNINI','GOFFIN','CARRENO','NISHIKORI',
                        'SHAPOVALOV','EDMUND','PAIRE','DelPOTRO','BEDENE','VINOLAS','GOJOWCZYK','KOHLSCHREIBER',
                        'DZUMHUR','BERRETTINI','DIMITROV','HARRISON','TSITSIPAS','THIEM','ANDERSON','ISNER',
                        'CECCHINATO','JOHNSON','BASILASHVILI','SOCK','SCHWARTZMAN','POUILLE','SONEGO','HAASE'],
                       
                        '2019':['NADAL','DJOKOVIC','SCHWARTZMAN','TSITSIPAS',
                                'DelPOTRO','VERDASCO','FEDERER','NISHIKORI',
                        'KOHLSCHREIBER','BASILASHVILI','CORIC','STRUFF','RUUD','FOGNINI','KHACHANOV','BERRETTINI',
                        'SHAPOVALOV','CHARDY','SOUSA','ZVEREV','THIEM','FRITZ','GOFFIN','SINNER',
                        'CILIC','ALBOT','BAUTISTA','NORRIE','DJERE','CECCHINATO','KYRGIOS','VINOLAS'],
                       
                        '2020':['DJOKOVIC','SCHWARTZMAN','RUUD','SHAPOVALOV',
                                'KOEPFER','NADAL','BERRETTINI','DIMITROV',
                        'KRAJINOVIC','LAJOVIC','TRAVAGLIA','HURKACZ','HUMBERT','SINNER','MUSETTI','CILIC',
                        'CARUSO','CARRENO','TSITSIPAS','CORIA','MONFILS','GOFFIN','FOGNINI','MILLMAN',
                        'RUBLEV','MARTINEZ','RAONIC','NISHIOKA','CECCHINATO','NISHIKORI','SONEGO','CORIC'],
                       
                        '2021':['NADAL','DJOKOVIC','SONEGO','OPELKA',
                                'TSITSIPAS','ZVEREV','RUBLEV','DelBONIS',
                        'FOKINA','SHAPOVALOV','THIEM','BERRETTINI','NISHIKORI','BAUTISTA','ALIASSIME','KARATSEV',
                        'FRITZ','SINNER','MEDVEDEV','FUCSOVICS','CILIC','DELLIEN','STRUFF','SCHWARTZMAN',
                        'MILLMAN','GARIN','CARRENO','GOFFIN','TRAVAGLIA','NORRIE','MUSETTI','MAGER'] }

# %%
Rome_PLACEMENTS_DATA = pd.DataFrame( Rome_placements_dict )
Rome_PLACEMENTS_DATA = Rome_PLACEMENTS_DATA.T
Rome_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Rome_PLACEMENTS_DATA
# Out:
#         winner     finalist        semi1       semi2         q1        q2  \
# 2014  DJOKOVIC        NADAL     DIMITROV      RAONIC     MURRAY    FERRER
# 2015  DJOKOVIC      FEDERER       FERRER    WAWRINKA  NISHIKORI   BERDYCH
# 2016    MURRAY     DJOKOVIC    NISHIKORI     POUILLE      NADAL    GOFFIN
# 2017    ZVEREV     DJOKOVIC        THIEM       ISNER   DelPOTRO     NADAL
# 2018     NADAL       ZVEREV     DJOKOVIC       CILIC    FOGNINI    GOFFIN
# 2019     NADAL     DJOKOVIC  SCHWARTZMAN   TSITSIPAS   DelPOTRO  VERDASCO
# 2020  DJOKOVIC  SCHWARTZMAN         RUUD  SHAPOVALOV    KOEPFER     NADAL
# 2021     NADAL     DJOKOVIC       SONEGO      OPELKA  TSITSIPAS    ZVEREV
#
#               q3         q4             o1             o2  ...        32_7  \
# 2014      CHARDY       HAAS        YOUZHNY  KOHLSCHREIBER  ...  GRANOLLERS
# 2015       NADAL     GOFFIN       BELLUCCI       ANDERSON  ...     GASQUET
# 2016       THIEM     MONACO       BELLUCCI         CHARDY  ...     VINOLAS
# ...

# %%
Rome_PLACEMENTS_DATA.to_excel("Rome_PLACEMENTS_DATA.xlsx")
