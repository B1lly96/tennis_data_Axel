# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Madrid_dict = {'2014':['NADAL','NISHIKORI','BAUTISTA','FERRER',
                       'BERDYCH','GULBIS','LOPEZ','GIRALDO',
               'NIEMINEN','ISNER','DIMITROV','MURRAY','RAONIC','KUBOT','CILIC','THIEM',
               'MONACO','WAWRINKA','VINOLAS','ANDERSON','ALMAGRO','CHARDY','MATOSEVIC','GARCIA',
               'TSONGA','COPIL','YOUZHNY','VERDASCO','MATHIEU','DOLGOPOLOV','SIMON','SIJSLING'],
              
               '2015':['MURRAY','NADAL','NISHIKORI','BERDYCH',
                       'RAONIC','DIMITROV','FERRER','ISNER',
               'GRANOLLERS','BOLELLI','BAUTISTA','MAYER','TSONGA','VERDASCO','WAWRINKA','KYRGIOS',
               'FEDERER','KOHLSCHREIBER','JOHNSON','GOFFIN','MONACO','GASQUET','VINOLAS','SOUSA',
               'CILIC','FOGNINI','LOPEZ','SOCK','MONFILS','QUERREY','BELLUCCI','VANNI'],
              
               '2016':['DJOKOVIC','MURRAY','NISHIKORI','NADAL',
                       'RAONIC','BERDYCH','SOUSA','KYRGIOS',
               'BAUTISTA','SIMON','QUERREY','GASQUET','TSONGA','FERRER','CUEVAS','SOCK',
               'CORIC','STEPANEK','WAWRINKA','KUZNETSOV','FOGNINI','VINOLAS','ISTOMIN','KUDLA',
               'VERDASCO','DOLGOPOLOV','MONFILS','LOPEZ','CARRENO','POUILLE','DelPOTRO','GRANOLLERS'],
              
               '2017':['NADAL','THIEM','DJOKOVIC','CUEVAS',
                       'NISHIKORI','GOFFIN','CORIC','ZVEREV',
               'MURRAY','LOPEZ','KYRGIOS','RAONIC','FERRER','DIMITROV','BERDYCH','PAIRE',
               'COPIL','ALMAGRO','WAWRINKA','FOGNINI','MULLER','SCHWARTZMAN','CILIC','DONALDSON',
               'FlorianMAYER','TSONGA','HAASE','KARLOVIC','HARRISON','HERBERT','MAHUT','SIMON'],
              
               '2018':['ZVEREV','THIEM','SHAPOVALOV','ANDERSON',
                       'NADAL','ISNER','LAJOVIC','EDMUND',
               'SCHWARTZMAN','MAYER','DelPOTRO','CORIC','KOHLSCHREIBER','CUEVAS','GOFFIN','RAONIC',
               'MONFILS','DONSKOY','DIMITROV','DZUMHUR','DelBONIS','KUKUSHKIN','HARRISON','HAASE',
               'DJOKOVIC','BAUTISTA','LOPEZ','STRUFF','VINOLAS','GASQUET','VERDASCO','PAIRE'],
              
               '2019':['DJOKOVIC','TSITSIPAS','THIEM','NADAL',
                       'CILIC','WAWRINKA','ZVEREV','FEDERER',
               'CHARDY','TIAFOE','HURKACZ','MONFILS','FOGNINI','NISHIKORI','VERDASCO','DJERE',
               'FRITZ','ALIASSIME','FERRER','GASQUET','OPELKA','DELLIEN','DelPOTRO','MANNARINO',
               'STRUFF','MILLMAN','KHACHANOV','FUCSOVICS','SCHWARTZMAN','POUILLE','KOHLSCHREIBER','PELLA'],
              
               '2020': lista_NaN,
              
               '2021':['ZVEREV','BERRETTINI','THIEM','RUUD',
                       'NADAL','ISNER','GARIN','BUBLIK',
               'POPYRIN','MEDVEDEV','DeMINAUR','TSITSIPAS','EVANS','RUBLEV','DelBONIS','KARATSEV',
               'ALCARAZ','FOKINA','GIRON','PAIRE','NISHIKORI','PAUL','SCHWARTZMAN','FOGNINI',
               'BAUTISTA','SHAPOVALOV','SINNER','KOEPFER','HARRIS','VINOLAS','MILLMAN','NISHIOKA'] }

# %%
Madrid_placements_data = pd.DataFrame( Madrid_dict )
Madrid_placements_data = Madrid_placements_data.T
Madrid_placements_data.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Madrid_placements_data
# Out:
#         winner    finalist       semi1     semi2         q1        q2  \
# 2014     NADAL   NISHIKORI    BAUTISTA    FERRER    BERDYCH    GULBIS
# 2015    MURRAY       NADAL   NISHIKORI   BERDYCH     RAONIC  DIMITROV
# 2016  DJOKOVIC      MURRAY   NISHIKORI     NADAL     RAONIC   BERDYCH
# 2017     NADAL       THIEM    DJOKOVIC    CUEVAS  NISHIKORI    GOFFIN
# 2018    ZVEREV       THIEM  SHAPOVALOV  ANDERSON      NADAL     ISNER
# 2019  DJOKOVIC   TSITSIPAS       THIEM     NADAL      CILIC  WAWRINKA
# 2020       NaN         NaN         NaN       NaN        NaN       NaN
# 2021    ZVEREV  BERRETTINI       THIEM      RUUD      NADAL     ISNER
#
#            q3       q4           o1        o2  ...         32_7       32_8  \
# 2014    LOPEZ  GIRALDO     NIEMINEN     ISNER  ...    MATOSEVIC     GARCIA
# 2015   FERRER    ISNER   GRANOLLERS   BOLELLI  ...      VINOLAS      SOUSA
# 2016    SOUSA  KYRGIOS     BAUTISTA     SIMON  ...      ISTOMIN      KUDLA
# ...

# %%
Madrid_placements_data.to_excel("Madrid_placements_data.xlsx")
