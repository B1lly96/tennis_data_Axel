# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

MonteCarlo_dict = {'2014':['WAWRINKA','FEDERER','DJOKOVIC','FERRER',
                           'NADAL','GARCIA','RAONIC','TSONGA',
                   'SEPPI','CARRENO','ALMAGRO','ROSOL','BERDYCH','DIMITROV','ROBREDO','FOGNINI',
                   'GABASHVILI','MONTANES','CILIC','STEPANEK','TURSUNOV','CHARDY','LU','KOHLSCHREIBER',
                   'BAUTISTA','BENNETEAU','VINOLAS','MAHUT','DOLGOPOLOV','MONFILS','LLODRA','ANDUJAR'],
                  
                   '2015':['DJOKOVIC','BERDYCH','NADAL','MONFILS',
                           'CILIC','FERRER','RAONIC','DIMITROV',
                   'HaiderMAURER','FEDERER','ISNER','ROBREDO','SIMON','BAUTISTA','WAWRINKA','TSONGA',
                   'VINOLAS','CHARDY','POUILLE','SOUSA','EstrellaBURGOS','STAKHOVSKY','MONACO','FlorianMAYER',
                   'FOGNINI','PAIRE','GOFFIN','KOHLSCHREIBER','DOLGOPOLOV','TROICKI','GRANOLLERS','TOMIC'],
                  
                   '2016':['NADAL','MONFILS','MURRAY','TSONGA',
                           'RAONIC','FEDERER','WAWRINKA','GRANOLLERS',
                   'PAIRE','BAUTISTA','SIMON','THIEM','POUILLE','DZUMHUR','GOFFIN','VESELY',
                   'DJOKOVIC','HERBERT','GARCIA','KOHLSCHREIBER','BEDENE','BERDYCH','CARRENO','GASQUET',
                   'CUEVAS','VERDASCO','DANIEL','LORENZI','CHARDY','DIMITROV','SOUSA','ZVEREV'],
                  
                   '2017':['NADAL','VINOLAS','GOFFIN','POUILLE',
                           'DJOKOVIC','SCHWARTZMAN','CILIC','CUEVAS',
                   'MURRAY','CARRENO','WAWRINKA','ZVEREV','BERDYCH','THIEM','MANNARINO','STRUFF',
                   'MULLER','SIMON','VESELY','EDMUND','CHARDY','HAASE','TSONGA','DIMITROV',
                   'HAAS','ALMAGRO','LORENZI','BAUTISTA','KHACHANOV','LOPEZ','BERLOCQ','SOUSA'],
                  
                   '2018':['NADAL','NISHIKORI','DIMITROV','ZVEREV',
                           'THIEM','CILIC','GASQUET','GOFFIN',
                   'KHACHANOV','RAONIC','STRUFF','KOHLSCHREIBER','DJOKOVIC','BAUTISTA','MischaZVEREV','SEPPI',
                   'BEDENE','VERDASCO','MULLER','HERBERT','RUBLEV','TSITSIPAS','POUILLE','CORIC',
                   'SCHWARTZMAN','LOPEZ','FOGNINI','CECCHINATO','VINOLAS','SIMON','MEDVEDEV','GARCIA'],
                  
                   '2019':['FOGNINI','LAJOVIC','NADAL','MEDVEDEV',
                           'DJOKOVIC','PELLA','CORIC','SONEGO',
                   'FRITZ','DIMITROV','ZVEREV','THIEM','TSITSIPAS','HERBERT','CECCHINATO','NORRIE',
                   'KOHLSCHREIBER','BAUTISTA','ALIASSIME','KLIZAN','NISHIKORI','KUKUSHKIN','CILIC','KHACHANOV',
                   'MUNAR','ALBOT','WAWRINKA','SIMON','GOFFIN','STRUFF','SCHWARTZMAN','FUCSOVICS'],
                  
                   '2020':lista_NaN,
                  
                   '2021':['TSITSIPAS','RUBLEV','EVANS','RUUD',
                           'NADAL','FOKINA','GOFFIN','FOGNINI',
                   'DJOKOVIC','DIMITROV','GARIN','ZVEREV','BAUTISTA','CARRENO','KRAJINOVIC','POUILLE',
                   'SINNER','DelBONIS','KARATSEV','SONEGO','CARUSO','SCHWARTZMAN','BERRETTINI','PAUL',
                   'CECCHINATO','KHACHANOV','HURKACZ','CHARDY','THOMPSON','MILLMAN','LONDERO','POPYRIN'] }

MonteCarlo_dict
# Out:
# {'2014': ['WAWRINKA',
#   'FEDERER',
#   'DJOKOVIC',
#   'FERRER',
#   'NADAL',
#   'GARCIA',
#   'RAONIC',
#   'TSONGA',
#   'SEPPI',
#   'CARRENO',
#   'ALMAGRO',
#   'ROSOL',
#   'BERDYCH',
#   'DIMITROV',
#   'ROBREDO',
#   'FOGNINI',
#   'GABASHVILI',
#   'MONTANES',
#   'CILIC',
#   'STEPANEK',
#   'TURSUNOV',
#   'CHARDY',
#   'LU',
#   'KOHLSCHREIBER',
#   'BAUTISTA',
#   'BENNETEAU',
#   'VINOLAS',
#   'MAHUT',
#   'DOLGOPOLOV',
#   'MONFILS',
#   'LLODRA',
#   'ANDUJAR'],
#  '2015': ['DJOKOVIC',
#   'BERDYCH',
#   'NADAL',
#   'MONFILS',
#   'CILIC',
#   'FERRER',
#   'RAONIC',
#   'DIMITROV',
#   'HaiderMAURER',
#   'FEDERER',
#   'ISNER',
#   'ROBREDO',
#   'SIMON',
#   'BAUTISTA',
#   'WAWRINKA',
#   'TSONGA',
#   'VINOLAS',
#   'CHARDY',
#   'POUILLE',
#   'SOUSA',
#   'EstrellaBURGOS',
#   'STAKHOVSKY',
#   'MONACO',
#   'FlorianMAYER',
#   'FOGNINI',
#   'PAIRE',
#   'GOFFIN',
#   'KOHLSCHREIBER',
#   'DOLGOPOLOV',
#   'TROICKI',
#   'GRANOLLERS',
#   'TOMIC'],
# ...

# %%
MonteCarlo_PLACEMENTS_DATA = pd.DataFrame( MonteCarlo_dict )
MonteCarlo_PLACEMENTS_DATA = MonteCarlo_PLACEMENTS_DATA.T
MonteCarlo_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
MonteCarlo_PLACEMENTS_DATA
# Out:
#          winner   finalist     semi1     semi2        q1           q2  \
# 2014   WAWRINKA    FEDERER  DJOKOVIC    FERRER     NADAL       GARCIA
# 2015   DJOKOVIC    BERDYCH     NADAL   MONFILS     CILIC       FERRER
# 2016      NADAL    MONFILS    MURRAY    TSONGA    RAONIC      FEDERER
# 2017      NADAL    VINOLAS    GOFFIN   POUILLE  DJOKOVIC  SCHWARTZMAN
# 2018      NADAL  NISHIKORI  DIMITROV    ZVEREV     THIEM        CILIC
# 2019    FOGNINI    LAJOVIC     NADAL  MEDVEDEV  DJOKOVIC        PELLA
# 2020        NaN        NaN       NaN       NaN       NaN          NaN
# 2021  TSITSIPAS     RUBLEV     EVANS      RUUD     NADAL       FOKINA
#
#             q3          q4            o1        o2  ...        32_7  \
# 2014    RAONIC      TSONGA         SEPPI   CARRENO  ...          LU
# 2015    RAONIC    DIMITROV  HaiderMAURER   FEDERER  ...      MONACO
# 2016  WAWRINKA  GRANOLLERS         PAIRE  BAUTISTA  ...     CARRENO
# ...

# %%
MonteCarlo_PLACEMENTS_DATA.to_excel("MonteCarlo_PLACEMENTS_DATA.xlsx")
