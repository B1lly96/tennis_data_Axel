# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

INDIAN_WELLS_1000_dict = {'2014':['DJOKOVIC','FEDERER','ISNER','DOLGOPOLOV',
                                  'BENNETEAU','ANDERSON','RAONIC','GULBIS',
                          'CILIC','WAWRINKA','MURRAY','HAAS','VERDASCO','FOGNINI','BAUTISTA','LOPEZ',
                          'NADAL','GONZALEZ','SEPPI','VESELY','TURSUNOV','GASQUET','FALLA','NISHIKORI',
                          'LU','MONFILS','DIMITROV','ROBREDO','DONSKOY','NIEMINEN','THIEM','KUKUSHKIN'],
                         
                          '2015':['DJOKOVIC','FEDERER','MURRAY','RAONIC',
                                  'TOMIC','BERDYCH','NADAL','LOPEZ',
                          'ISNER','SOCK','SIMON','MANNARINO','NISHIKORI','ROBREDO','ROSOL','KOKKINAKIS',
                          'VINOLAS','SEPPI','YOUNG','KOHLSCHREIBER','VERDASCO','DOLGOPOLOV','FERRER','JOHNSON',
                          'DIMITROV','CUEVAS','BERRER','GULBIS','BAUTISTA','ANDERSON','HAASE','MONACO'],
                         
                          '2016':['DJOKOVIC','RAONIC','NADAL','GOFFIN',
                                  'TSONGA','NISHIKORI','CILIC','MONFILS',
                          'LOPEZ','WAWRINKA','ZVEREV','ISNER','BERDYCH','THIEM','GASQUET','DelBONIS',
                          'KOHLSCHREIBER','MURRAY','KUZNETSOV','VERDASCO','JOHNSON','CORIC','QUERREY','DOLGOPOLOV',
                          'MANNARINO','MAYER','SOCK','TOMIC','VINOLAS','BAUTISTA','PELLA','SIMON'],
                         
                          '2017':['FEDERER','WAWRINKA','CARRENO','SOCK',
                                  'THIEM','NISHIKORI','KYRGIOS','CUEVAS',
                          'DJOKOVIC','NISHIOKA','YOUNG','NADAL','MONFILS','GOFFIN','JAZIRI','LAJOVIC',
                          'DelPOTRO','KOHLSCHREIBER','MULLER','VERDASCO','MischaZVEREV','JOHNSON','ISNER','VINOLAS',
                          'DIMITROV','BERDYCH','POUILLE','ZVEREV','BAUTISTA','FOGNINI','FRITZ','POSPISIL'],
                         
                          '2018':['DelPOTRO','FEDERER','CORIC','RAONIC',
                                  'CHUNG','KOHLSCHREIBER','ANDERSON','QUERREY',
                          'CHARDY','MAYER','CARRENO','LOPEZ','CUEVAS','HERBERT','BAGHDATIS','FRITZ',
                          'KRAJINOVIC','CILIC','THIEM','FERRER','KICKER','SOCK','MEDVEDEV','BERDYCH',
                          'BAUTISTA','BHAMBRI','MANNARINO','SOUSA','SELA','VERDASCO','MONFILS','DANIEL'],
                         
                          '2019':['THIEM','FEDERER','NADAL','RAONIC',
                                  'KHACHANOV','HURKACZ','MONFILS','KECMANOVIC',
                          'KRAJINOVIC','EDMUND','KARLOVIC','ISNER','STRUFF','KOHLSCHREIBER','SHAPOVALOV','NISHIOKA',
                          'DJOKOVIC','SCHWARTZMAN','ZVEREV','WAWRINKA','NISHIKORI','SIMON','PELLA','CILIC',
                          'RUBLEV','GIRON','MEDVEDEV','VINOLAS','ALBOT','DJERE','GUNNESWARAN','ALIASSIME'],
                         
                          '2020':lista_NaN,
                         
                          '2021':lista_NaN }

# %%
IndianWells_PLACEMENTS_DATA = pd.DataFrame( INDIAN_WELLS_1000_dict )
IndianWells_PLACEMENTS_DATA = IndianWells_PLACEMENTS_DATA.T
IndianWells_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
IndianWells_PLACEMENTS_DATA
# Out:
#         winner  finalist    semi1       semi2         q1             q2  \
# 2014  DJOKOVIC   FEDERER    ISNER  DOLGOPOLOV  BENNETEAU       ANDERSON
# 2015  DJOKOVIC   FEDERER   MURRAY      RAONIC      TOMIC        BERDYCH
# 2016  DJOKOVIC    RAONIC    NADAL      GOFFIN     TSONGA      NISHIKORI
# 2017   FEDERER  WAWRINKA  CARRENO        SOCK      THIEM      NISHIKORI
# 2018  DelPOTRO   FEDERER    CORIC      RAONIC      CHUNG  KOHLSCHREIBER
# 2019     THIEM   FEDERER    NADAL      RAONIC  KHACHANOV        HURKACZ
# 2020       NaN       NaN      NaN         NaN        NaN            NaN
# 2021       NaN       NaN      NaN         NaN        NaN            NaN
#
#             q3          q4          o1        o2  ...      32_7        32_8  \
# 2014    RAONIC      GULBIS       CILIC  WAWRINKA  ...     FALLA   NISHIKORI
# 2015     NADAL       LOPEZ       ISNER      SOCK  ...    FERRER     JOHNSON
# 2016     CILIC     MONFILS       LOPEZ  WAWRINKA  ...   QUERREY  DOLGOPOLOV
# ...

# %%
IndianWells_PLACEMENTS_DATA.to_excel("IndianWells_PLACEMENTS_DATA.xlsx")
