# %%
import pandas as pd
import numpy as np 

AUSTRALIAN_OPEN_PLACEMENTS = { '2021':['DJOKOVIC','MEDVEDEV','KARATSEV','TSITSIPAS',
                                       'ZVEREV','NADAL','RUBLEV','DIMITROV',
                                   'RAONIC','FOGNINI','THIEM','McDONALD','BERRETTINI','LAJOVIC','RUUD','ALIASSIME',
                                   'FRITZ','NORRIE','KYRGIOS','KRAJINOVIC','YMER','MANNARINO','LOPEZ','SCHWARTZMAN',
                                   'KHACHANOV','SHAPOVALOV','FUCSOVICS','CARRENO','DeMINAUR','MARTINEZ','ALBOT','HARRIS',
                                   'TIAFOE','MMOH','KOEPFER','CarballesBAENA','KOKKINAKIS','CRESSY','MONTEIRO','MULLER',
                                   'MACHAC','TOMIC','MOUTET','VESELY','CARUSO','WAWRINKA','BOLT','BERANKIS',
                                   'DUCKWORTH','CUEVAS','CORIC','BUBLIK','PAUL','OPELKA','ANDUJAR','HUMBERT',
                                   'SONEGO','KECMANOVIC','OCONNELL','POPYRIN','GERASIMOV','RUUSUVUORI','SAFIULLIN','ALCARAZ'],
    
                               '2020':['DJOKOVIC','THIEM','FEDERER','ZVEREV',
                                       'NADAL','RAONIC','SANDGREN','WAWRINKA',
                                  'KYRGIOS','SCHWARTZMAN','FUCSOVICS','MEDVEDEV','MONFILS','RUBLEV','FOGNINI','CILIC',
                                  'CARRENO','NISHIOKA','MILLMAN','POPYRIN','FRITZ','TSITSIPAS','VERDASCO','BAUTISTA',
                                  'GULBIS','GOFFIN','PELLA','LAJOVIC','ISNER','KHACHANOV','PAUL','QUERREY',
                                  'DelBONIS','ITO','KRAJINOVIC','MARTINEZ','BOLT','KOHLSCHREIBER','GERASIMOV','BERRETTINI',
                                  'MMOH','KARLOVIC','HERBERT','THOMPSON','FOKINA','SEPPI','YMER','SUGITA',
                                  'DIMITROV','TABILO','PAIRE','BARRERE','SIMON','POLMANS','BASILASHVILI','GOJOWCZYK',
                                  'ANDERSON','EVANS','HURKACZ','GARIN','SINNER','BEDENE','MUNAR','BERANKIS'],
                               
                               '2019':['DJOKOVIC','NADAL','POUILLE','TSITSIPAS',
                                                  'NISHIKORI','TIAFOE','BAUTISTA','RAONIC',
                                  'MEDVEDEV','BERDYCH','FEDERER','ZVEREV','CILIC','CARRENO','CORIC','DIMITROV',
                                  'SHAPOVALOV','DeMINAUR','FRITZ','BOLT','VERDASCO','SOUSA','KHACHANOV','KRAJINOVIC',
                                  'FOGNINI','BASILASHVILI','GOFFIN','HERBERT','SCHWARTZMAN','FABBIANO','POPYRIN','SEPPI',
                                  'TSONGA','EBDEN','EVANS','CHARDY','ANDERSON','McDONALD','THIEM','KARLOVIC',
                                  'NISHIOKA','FUCSOVICS','MAYER','TROICKI','HARRISON','WAWRINKA','KUDLA','TRAVAGLIA',
                                  'CUEVAS','COPIL','MILLMAN','IVASHKA','CHUNG','DANIEL','ALBOT','LAAKSONEN',
                                  'MARTERER','SIMON','MONFILS','KOHLSCHREIBER','HAASE','OPELKA','DONSKOY','THOMPSON'],
                             
                                '2018':['FEDERER','CILIC','CHUNG','EDMUND',
                                                   'NADAL','BERDYCH','DIMITROV','SANDGREN',
                                  'SCHWARTZMAN','FUCSOVICS','KYRGIOS','THIEM','CARRENO','DJOKOVIC','FOGNINI','SEPPI',
                                  'DZUMHUR','GASQUET','RUBLEV','ZVEREV','MANNARINO','HARRISON','MULLER','DelPOTRO',
                                  'VINOLAS','TSONGA','DOLGOPOLOV','BENNETEAU','BASILASHVILI','KICKER','MARTERER','KARLOVIC',
                                  'MAYER','STRUFF','McDONALD','GOJOWCZYK','KUDLA','SOUSA','GOFFIN','WAWRINKA',
                                  'SIMON','KHACHANOV','QUERREY','MONFILS','SHAPOVALOV','TROICKI','GARCIA','SMYCZEK',
                                  'JAZIRI','RUUD','DONSKOY','VESELY','MILLMAN','SONEGO','BAGHDATIS','CUEVAS',
                                  'BEMELMANS','MEDVEDEV','EBDEN','ISTOMIN','SUGITA','LACKO','VERDASCO','NISHIOKA'],
                             
                               '2017':['FEDERER','NADAL','WAWRINKA','DIMITROV',
                                                  'RAONIC','TSONGA','GOFFIN','MischaZVEREV',
                                  'MURRAY','BAUTISTA','SEPPI','NISHIKORI','MONFILS','THIEM','EVANS','ISTOMIN',
                                  'QUERREY','SIMON','TROICKI','LACKO','KOHLSCHREIBER','PAIRE','ZVEREV','BERDYCH',
                                  'KARLOVIC','SOCK','FERRER','GASQUET','TOMIC','CARRENO','DARCIS','JAZIRI',
                                  'RUBLEV','DJOKOVIC','MULLER','JOHNSON','CHARDY','DOLGOPOLOV','CILIC','THOMPSON',
                                  'BAGHDATIS','HARRISON','STEPANEK','LAJOVIC','NISHIOKA','KYRGIOS','CHUNG','RUBIN',
                                  'BERLOCQ','ISNER','WHITTINGTON','ESCOBEDO','KHACHANOV','TIAFOE','DutraSILVA','BURGOS',
                                  'LORENZI','EDMUND','DeMINAUR','YOUNG','SCHWARTZMAN','BUBLIK','SELA','FOGNINI'],
                                
                              '2016':['DJOKOVIC','MURRAY','FEDERER','RAONIC',
                                                 'NISHIKORI','FERRER','BERDYCH','MONFILS',
                                  'SIMON','TOMIC','GOFFIN','WAWRINKA','BAUTISTA','TSONGA','ISNER','KUZNETSOV',
                                  'SEPPI','SOUSA','DIMITROV','ROSOL','KYRGIOS','GARCIA','JOHNSON','HERBERT',
                                  'LOPEZ','CILIC','TROICKI','DelBONIS','THIEM','MILLMAN','ROBERT','SELA',
                                  'HALYS','GROTH','DOLGOPOLOV','STEPANEK','BASIC','KRAJICEK','HEWITT','JASIKA',
                                  'GRANOLLERS','VINOLAS','ROBREDO','DONSKOY','DZUMHUR','BOLELLI','PELLA','ALMAGRO',
                                  'SMYCZEK','MAHUT','LAJOVIC','SOCK','BRANDS','TRUNGELLITI','KUDLA','CUEVAS',
                                  'CHARDY','BELLUCCI','GIRALDO','OLIVO','RUBIN','MULLER','RAM','VERDASCO'],
            
                              '2015':['DJOKOVIC','MURRAY','WAWRINKA','BERDYCH',
                                                 'RAONIC','NADAL','NISHIKORI','KYRGIOS',
                                  'MULLER','ANDERSON','GARCIA','FERRER','DIMITROV','TOMIC','LOPEZ','SEPPI',
                                  'VERDASCO','FEDERER','SELA','NIEMINEN','JOHNSON','SOUSA','TROICKI','BECKER',
                                  'SIMON','BAGHDATIS','JANOWICZ','GASQUET','ISNER','POSPISIL','JAZIRI','GROTH',
                                  'KUZNETSOV','BOLELLI','SMYCZEK','COPIL','DODIG','MATOSEVIC','MELZER','YOUNG',
                                  'STAKHOVSKY','LACKO','MANNARINO','BAUTISTA','BERANKIS','MONFILS','GRANOLLERS','HaiderMAURER',
                                  'GOFFIN','KOHLSCHREIBER','KARLOVIC','DUCKWORTH','MAYER','ROSOL','CHARDY','GIRALDO',
                                  'SOEDA','KLIZAN','HEWITT','GONZALEZ','KOKKINAKIS','VASSELIN','BACHINGER','LORENZI'],
                              
                              '2014':['WAWRINKA','NADAL','FEDERER','BERDYCH',
                                                 'DIMITROV','DJOKOVIC','FERRER','MURRAY',
                                  'NISHIKORI','FOGNINI','FlorianMAYER','ROBERT','TSONGA','ANDERSON','ROBREDO','BAUTISTA',
                                  'MONFILS','ISTOMIN','CHARDY','LOPEZ','GABASHVILI','DZUMHUR','POSPISIL','GASQUET',
                                  'SIMON','RAONIC','QUERREY','YOUNG','VASSELIN','JANOWICZ','PAIRE','KLIZAN',
                                  'KOKKINAKIS','MAYER','MANNARINO','MILLOT','DelPOTRO','KAVCIC','DeSCHEPPER','FALLA',
                                  'DAVYDENKO','BELLUCCI','HANESCU','YOUZHNY','NIEMINEN','LAJOVIC','BENNETEAU','CILIC',
                                  'THIEM','ANDUJAR','LU','GULBIS','SEPPI','SOCK','BERRER','KYRGIOS',
                                  'EBDEN','DOLGOPOLOV','TURSUNOV','VERDASCO','DODIG','ROLA','PRZYSIEZNY','GARCIA'] }

# %%
AUSTRALIAN_OPEN_PLACEMENTS_DATA = pd.DataFrame( AUSTRALIAN_OPEN_PLACEMENTS )
AUSTRALIAN_OPEN_PLACEMENTS_DATA = AUSTRALIAN_OPEN_PLACEMENTS_DATA.T
AUSTRALIAN_OPEN_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16',
                                         '64_1','64_2','64_3','64_4','64_5','64_6','64_7','64_8',
                                         '64_9','64_10','64_11','64_12','64_13','64_14','64_15','64_16',
                                         '64_17','64_18','64_19','64_20','64_21','64_22','64_23','64_24',
                                         '64_25','64_26','64_27','64_28','64_29','64_30','64_31','64_32']
AUSTRALIAN_OPEN_PLACEMENTS_DATA
# Out:
#         winner  finalist     semi1      semi2         q1        q2         q3  \
# 2021  DJOKOVIC  MEDVEDEV  KARATSEV  TSITSIPAS     ZVEREV     NADAL     RUBLEV
# 2020  DJOKOVIC     THIEM   FEDERER     ZVEREV      NADAL    RAONIC   SANDGREN
# 2019  DJOKOVIC     NADAL   POUILLE  TSITSIPAS  NISHIKORI    TIAFOE   BAUTISTA
# 2018   FEDERER     CILIC     CHUNG     EDMUND      NADAL   BERDYCH   DIMITROV
# 2017   FEDERER     NADAL  WAWRINKA   DIMITROV     RAONIC    TSONGA     GOFFIN
# 2016  DJOKOVIC    MURRAY   FEDERER     RAONIC  NISHIKORI    FERRER    BERDYCH
# 2015  DJOKOVIC    MURRAY  WAWRINKA    BERDYCH     RAONIC     NADAL  NISHIKORI
# 2014  WAWRINKA     NADAL   FEDERER    BERDYCH   DIMITROV  DJOKOVIC     FERRER
#
#                 q4           o1           o2  ...         64_23      64_24  \
# 2021      DIMITROV       RAONIC      FOGNINI  ...       ANDUJAR    HUMBERT
# 2020      WAWRINKA      KYRGIOS  SCHWARTZMAN  ...  BASILASHVILI  GOJOWCZYK
# ...

# %%
AUSTRALIAN_OPEN_PLACEMENTS_DATA.to_excel("AUSTRALIAN_OPEN_PLACEMENTS_DATA.xlsx")
