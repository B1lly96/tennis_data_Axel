# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(64) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 64
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

RolandGarros_placement_dict = {'2021' : lista_NaN,
                              
                               '2020':['NADAL','DJOKOVIC','TSITSIPAS','SCHWARTZMAN',
                                       'CARRENO','SINNER','THIEM','RUBLEV',
                               'KHACHANOV','KORDA','GASTON','DIMITROV','ZVEREV','SONEGO','FUCSOVICS','ALTMAIER',
                               'GALAN','TRAVAGLIA','RUUD','BEDENE','CECCHINATO','BERRETTINI','BAUTISTA','GOMBOS',
                               'ANDERSON','GARIN','WAWRINKA','CarballesBAENA','FRITZ','MONTEIRO','MARTINEZ','CORIA',
                               'BERANKIS','McDONALD','SOCK','CUEVAS','HERBERT','HARRIS','SHAPOVALOV','BALAZS',
                               'GIUSTINO','FOKINA','VESELY','KOEPFER','PELLA','MARTIN','POLMANS','ISNER',
                               'LAJOVIC','PAIRE','ALBOT','PAUL','STRUFF','MILOJEVIC','LONDERO','VINOLAS',
                               'SANDGREN','NISHIOKA','RODIONOV','KUKUSHKIN','GIRON','BONZI','BUBLIK','NISHIKORI'],
                              
                               '2019':['NADAL','THIEM','DJOKOVIC','FEDERER',
                                       'ZVEREV','NISHIKORI','WAWRINKA','KHACHANOV',
                               'STRUFF','LONDERO','MAYER','MONFILS','FOGNINI','TSITSIPAS','PAIRE','DelPOTRO',
                               'CARUSO','GOFFIN','RUUD','CUEVAS','LAJOVIC','KRAJINOVIC','DJERE','THOMPSON',
                               'BAUTISTA','KLIZAN','CORIC','HOANG','DIMITROV','MOUTET','MAHUT','CARRENO',
                               'LAAKSONEN','MADEN','OTTE','BUBLIK','YMER','DELLIEN','TSONGA','NISHIOKA',
                               'DelBONIS','BARRERE','CILIC','HARRIS','MANNARINO','SCHWARTZMAN','FRITZ','PELLA',
                               'DeMINAUR','POUILLE','VERDASCO','GARIN','SIMON','KECMANOVIC','EDMUND','BERRETTINI',
                               'BENCHETRIT','POPYRIN','CarballesBAENA','GASQUET','KOHLSCHREIBER','HERBERT','ALBOT','KARLOVIC'],
                              
                               '2018':['NADAL','THIEM','DelPOTRO','CECCHINATO',
                                       'SCHWARTZMAN','ZVEREV','CILIC','DJOKOVIC',
                               'MARTERER','KHACHANOV','FOGNINI','ISNER','ANDERSON','NISHIKORI','GOFFIN','VERDASCO',
                               'GASQUET','DZUMHUR','JOHNSON','DIMITROV','VINOLAS','MischaZVEREV','BERRETTINI','MONFILS',
                               'HERBERT','CARRENO','CORIC','BAUTISTA','POUILLE','EDMUND','SIMON','ZOPP',
                               'PELLA','LAJOVIC','HURKACZ','DONALDSON','BENNETEAU','CUEVAS','TSITSIPAS','MOUTET',
                               'ZEBALLOS','DelBONIS','PAVLASEK','QUERREY','GIRALDO','NORRIE','FUCSOVICS','YMER',
                               'PAIRE','MUNAR','SHAPOVALOV','ALBOT','JAZIRI','ANDREOZZI','RUUD','KLIZAN',
                               'GULBIS','TRUNGELLITI','FABBIANO','CHARDY','STRUFF','GARCIA','BEMELMANS','STAKHOVSKY'],
                              
                               '2017':['NADAL','WAWRINKA','MURRAY','THIEM',
                                       'NISHIKORI','DJOKOVIC','CILIC','CARRENO',
                               'KHACHANOV','VINOLAS','MONFILS','BAUTISTA','RAONIC','ZEBALLOS','ANDERSON','VERDASCO',
                               'DelPOTRO','SCHWARTZMAN','FOGNINI','BASILASHVILI','GARCIA','JOHNSON','LOPEZ','CHUNG',
                               'GOFFIN','DIMITROV','GASQUET','POUILLE','VESELY','ISNER','CUEVAS','EDMUND',
                               'KLIZAN','SOUSA','DOLGOPOLOV','HAASE','DutraSILVA','BOLELLI','KRAVCHUK','CHARDY',
                               'STAKHOVSKY','ROBREDO','BERDYCH','MONTEIRO','BELLUCCI','KUKUSHKIN','KYRGIOS','BONZI',
                               'DANIEL','LORENZI','KICKER','KARLOVIC','EstrellaBURGOS','CORIC','SEPPI','ALMAGRO',
                               'FERRER','TROICKI','ISTOMIN','OLIVO','TRUNGELLITI','NAPOLITANO','HERBERT','BEDENE'],
                              
                               '2016':['DJOKOVIC','MURRAY','THIEM','WAWRINKA',
                                       'BERDYCH','GASQUET','VINOLAS','GOFFIN',
                               'BAUTISTA','ISNER','TROICKI','NISHIKORI','FERRER','RAONIC','GULBIS','GRANOLLERS',
                               'BEDENE','KARLOVIC','CHARDY','NADAL','VERDASCO','TSONGA','CUEVAS','MARTIN',
                               'KYRGIOS','LOPEZ','ALMAGRO','ZVEREV','CORIC','GABASHVILI','SIMON','SOCK',
                               'DARCIS','BOURGUE','DANIEL','BAGNIS','KUZNETSOV','BAGHDATIS','JAZIRI','MANNARINO',
                               'FRATANGELO','MONACO','BERLOCQ','GARCIA','MATHIEU','EDMUND','PELLA','SIJSLING',
                               'PAIRE','TOMIC','EstrellaBURGOS','LAJOVIC','BROWN','HALYS','SOUSA','THOMPSON',
                               'POUILLE','PAVLASEK','VESELY','CARRENO','MAHUT','TRUNGELLITI','DODIG','ROBERT'],
                              
                               '2015':['WAWRINKA','DJOKOVIC','MURRAY','TSONGA',
                                       'NADAL','FEDERER','FERRER','NISHIKORI',
                               'GASQUET','MONFILS','CHARDY','BERDYCH','GABASHVILI','SOCK','CILIC','SIMON',
                               'KOKKINAKIS','DZUMHUR','KYRGIOS','PAIRE','BECKER','KUZNETSOV','BOLELLI','JOHNSON',
                               'MAYER','MAHUT','CUEVAS','ANDUJAR','ANDERSON','GOFFIN','ROSOL','CORIC',
                               'MULLER','GRANOLLERS','SOUSA','STEPANEK','BELLUCCI','ALMAGRO','GimenoTRAVER','LAJOVIC',
                               'ARNABOLDI','KLIZAN','SCHWARTZMAN','SELA','LU','ISNER','GIRALDO','ROBREDO',
                               'BAUTISTA','BERLOCQ','THIEM','KOHLSCHREIBER','JANOWICZ','GULBIS','TOMIC','FOGNINI',
                               'EDMUND','TROICKI','VERDASCO','BAGHDATIS','MONACO','STAKHOVSKY','MELZER','CARRENO'],
                              
                               '2014':['NADAL','DJOKOVIC','MURRAY','GULBIS',
                                       'FERRER','RAONIC','BERDYCH','MONFILS',
                               'LAJOVIC','TSONGA','FEDERER','ANDERSON','ISNER','VERDASCO','GRANOLLERS','GARCIA',
                               'MAYER','CILIC','TURSUNOV','SEPPI','BAUTISTA','KOHLSCHREIBER','SIMON','ROBREDO',
                               'GASQUET','JANOWICZ','FOGNINI','STEPANEK','KARLOVIC','YOUNG','KLIZAN','SOCK',
                               'THIEM','CHARDY','SCHWARTZMAN','BOLELLI','NEDOVYESOV','MATOSEVIC','VESELY','KUKUSHKIN',
                               'BERLOCQ','MELZER','BELLUCCI','YOUZHNY','DeSCHEPPER','BAGNIS','MICHON','DOLGOPOLOV',
                               'NIEMINEN','STRUFF','CUEVAS','KAMKE','LOPEZ','PAIRE','ISTOMIN','GONZALEZ',
                               'QUERREY','MONACO','MANNARINO','HaiderMAURER','HAASE','ZOPP','GABASHVILI','JOHNSON'] }

# %%
RolandGarros_DATA = pd.DataFrame( RolandGarros_placement_dict )
RolandGarros_DATA = RolandGarros_DATA.T
RolandGarros_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16',
                                         '64_1','64_2','64_3','64_4','64_5','64_6','64_7','64_8',
                                         '64_9','64_10','64_11','64_12','64_13','64_14','64_15','64_16',
                                         '64_17','64_18','64_19','64_20','64_21','64_22','64_23','64_24',
                                         '64_25','64_26','64_27','64_28','64_29','64_30','64_31','64_32']
RolandGarros_DATA
# Out:
#         winner  finalist      semi1        semi2           q1         q2  \
# 2021       NaN       NaN        NaN          NaN          NaN        NaN
# 2020     NADAL  DJOKOVIC  TSITSIPAS  SCHWARTZMAN      CARRENO     SINNER
# 2019     NADAL     THIEM   DJOKOVIC      FEDERER       ZVEREV  NISHIKORI
# 2018     NADAL     THIEM   DelPOTRO   CECCHINATO  SCHWARTZMAN     ZVEREV
# 2017     NADAL  WAWRINKA     MURRAY        THIEM    NISHIKORI   DJOKOVIC
# 2016  DJOKOVIC    MURRAY      THIEM     WAWRINKA      BERDYCH    GASQUET
# 2015  WAWRINKA  DJOKOVIC     MURRAY       TSONGA        NADAL    FEDERER
# 2014     NADAL  DJOKOVIC     MURRAY       GULBIS       FERRER     RAONIC
#
#             q3         q4         o1         o2  ...    64_23       64_24  \
# 2021       NaN        NaN        NaN        NaN  ...      NaN         NaN
# 2020     THIEM     RUBLEV  KHACHANOV      KORDA  ...  LONDERO     VINOLAS
# 2019  WAWRINKA  KHACHANOV     STRUFF    LONDERO  ...   EDMUND  BERRETTINI
# ...

# %%
RolandGarros_DATA.to_excel("RolandGarros_DATA.xlsx")
