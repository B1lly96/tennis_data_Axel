# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Shanghai_placements_dict = {'2014':['FEDERER','SIMON','DJOKOVIC','LOPEZ',
                                    'FERRER','BENNETEAU','BERDYCH','YOUZHNY',
                            'KUKUSHKIN','BAUTISTA','MURRAY','KARLOVIC','ISNER','SOCK','JAZIRI','MONACO',
                            'THIEM','NADAL','MAYER','WAWRINKA','KLIZAN','GASQUET','NISHIKORI','RAONIC',
                            'DIMITROV','JANOWICZ','JOHNSON','POSPISIL','ANDERSON','WANG','LU','DODIG'],
                           
                            '2015':['DJOKOVIC','TSONGA','MURRAY','NADAL',
                                    'TOMIC','BERDYCH','WAWRINKA','ANDERSON',
                            'LOPEZ','ISNER','CILIC','SIMON','NISHIKORI','RAONIC','GASQUET','VINOLAS',
                            'KLIZAN','FEDERER','JOHNSON','TROICKI','SOCK','KYRGIOS','FERRER','KARLOVIC',
                            'BAUTISTA','MAYER','POSPISIL','FOGNINI','GOFFIN','CORIC','THIEM','EstrellaBURGOS'],
                           
                            '2016':['MURRAY','BAUTISTA','DJOKOVIC','SIMON',
                                    'MischaZVEREV','GOFFIN','TSONGA','SOCK',
                            'POSPISIL','POUILLE','WAWRINKA','RAONIC','MONFILS','ZVEREV','TROICKI','GRANOLLERS',
                            'FOGNINI','JOHNSON','EDMUND','NADAL','LORENZI','ANDERSON','BERDYCH','CILIC',
                            'TIPSAREVIC','PAIRE','KYRGIOS','ALMAGRO','FRITZ','DIMITROV','WU','LOPEZ'],
                           
                            '2017':['FEDERER','NADAL','CILIC','DelPOTRO',
                                    'DIMITROV','GASQUET','VINOLAS','TROICKI',
                            'FOGNINI','DOLGOPOLOV','ZVEREV','JOHNSON','QUERREY','ISNER','SIMON','STRUFF',
                            'DONALDSON','SCHWARTZMAN','BEDENE','EDMUND','THIEM','HARRISON','CARRENO','GOFFIN',
                            'TIAFOE','ANDERSON','TSITSIPAS','POUILLE','RUBLEV','LOPEZ','CHUNG','WU'],
                           
                            '2018':['DJOKOVIC','CORIC','FEDERER','ZVEREV',
                                    'NISHIKORI','ANDERSON','EDMUND','EBDEN',
                            'BAUTISTA','CECCHINATO','DelPOTRO','DeMINAUR','TSITSIPAS','QUERREY','JARRY','GOJOWCZYK',
                            'MEDVEDEV','CHARDY','GASQUET','BASILASHVILI','CILIC','THIEM','KUKUSHKIN','WU',
                            'KHACHANOV','SEPPI','KLAHN','CHUNG','McDONALD','PAIRE','FUCSOVICS','FRITZ'],
                           
                            '2019':['MEDVEDEV','ZVEREV','TSITSIPAS','BERRETTINI',
                                    'DJOKOVIC','FEDERER','FOGNINI','THIEM',
                            'ISNER','GOFFIN','POSPISIL','BASILASHVILI','RUBLEV','HURKACZ','KHACHANOV','BAUTISTA',
                            'SHAPOVALOV','VINOLAS','NORRIE','CARRENO','CHARDY','ALIASSIME','FRITZ','OPELKA',
                            'MONFILS','MURRAY','GARIN','KUKUSHKIN','PAIRE','POUILLE','SOUSA','MILLMAN'],
                           
                            '2020': lista_NaN,
                           
                            '2021': lista_NaN }

# %%
Shanghai_PLACEMENTS_DATA = pd.DataFrame( Shanghai_placements_dict )
Shanghai_PLACEMENTS_DATA = Shanghai_PLACEMENTS_DATA.T
Shanghai_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Shanghai_PLACEMENTS_DATA
# Out:
#         winner  finalist      semi1       semi2            q1         q2  \
# 2014   FEDERER     SIMON   DJOKOVIC       LOPEZ        FERRER  BENNETEAU
# 2015  DJOKOVIC    TSONGA     MURRAY       NADAL         TOMIC    BERDYCH
# 2016    MURRAY  BAUTISTA   DJOKOVIC       SIMON  MischaZVEREV     GOFFIN
# 2017   FEDERER     NADAL      CILIC    DelPOTRO      DIMITROV    GASQUET
# 2018  DJOKOVIC     CORIC    FEDERER      ZVEREV     NISHIKORI   ANDERSON
# 2019  MEDVEDEV    ZVEREV  TSITSIPAS  BERRETTINI      DJOKOVIC    FEDERER
# 2020       NaN       NaN        NaN         NaN           NaN        NaN
# 2021       NaN       NaN        NaN         NaN           NaN        NaN
#
#             q3        q4         o1          o2  ...       32_7      32_8  \
# 2014   BERDYCH   YOUZHNY  KUKUSHKIN    BAUTISTA  ...  NISHIKORI    RAONIC
# 2015  WAWRINKA  ANDERSON      LOPEZ       ISNER  ...     FERRER  KARLOVIC
# 2016    TSONGA      SOCK   POSPISIL     POUILLE  ...    BERDYCH     CILIC
# ...

# %%
Shanghai_PLACEMENTS_DATA.to_excel("Shanghai_PLACEMENTS_DATA.xlsx")
