# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

CANADA_dict = {'2014':['TSONGA','FEDERER','LOPEZ','DIMITROV',
                        'FERRER','RAONIC','ANDERSON','MURRAY',
                'DJOKOVIC','CILIC','WAWRINKA','BERDYCH','DODIG','BENNETEAU','ROBREDO','GASQUET',
                'MONFILS','POLANSKY','PAIRE','LU','RUSSELL','SOCK','YOUNG','KYRGIOS',
                'GULBIS','KARLOVIC','CHARDY','JAZIRI','FOGNINI','SIMON','SEPPI','SMYCZEK'],
               
                '2015':['MURRAY','DJOKOVIC','CHARDY','NISHIKORI',
                        'GULBIS','TSONGA','NADAL','ISNER',
                'SOCK','MULLER','GOFFIN','YOUZHNY','TOMIC','KYRGIOS','KARLOVIC','YOUNG',
                'BELLUCCI','ROBREDO','WAWRINKA','ANDUJAR','BERDYCH','CILIC','STAKHOVSKY','RAONIC',
                'SIMON','BAUTISTA','QUERREY','DIMITROV','MONFILS','POSPISIL','MAYER','ROSOL'],
               
                '2016':['DJOKOVIC','NISHIKORI','MONFILS','WAWRINKA',
                        'BERDYCH','ANDERSON','DIMITROV','RAONIC',
                'STEPANEK','SOCK','RAM','DONALDSON','HARRISON','GOFFIN','TOMIC','KARLOVIC',
                'MULLER','YOUZHNY','NOVIKOV','LU','CORIC','THIEM','QUERREY','CILIC',
                'ISNER','POSPISIL','DIEZ','POUILLE','YOUNG','SHAPOVALOV','FOGNINI','POLANSKY'],
               
                '2017':['ZVEREV','FEDERER','HAASE','SHAPOVALOV',
                        'BAUTISTA','ANDERSON','SCHWARTZMAN','MANNARINO',
                'NADAL','FERRER','KYRGIOS','DIMITROV','MONFILS','QUERREY','CHUNG','DONALDSON',
                'CORIC','POLANSKY','THIEM','GASQUET','NISHIKORI','RAONIC','MischaZVEREV','TSONGA',
                'GOFFIN','CARRENO','HARRISON','SOCK','LORENZI','PAIRE','ESCOBEDO','DelPOTRO'],
               
                '2018':['NADAL','TSITSIPAS','KHACHANOV','ANDERSON',
                        'CILIC','ZVEREV','DIMITROV','HAASE',
                'WAWRINKA','MEDVEDEV','IVASHKA','TIAFOE','SCHWARTZMAN','ISNER','DJOKOVIC','SHAPOVALOV',
                'PAIRE','KLAHN','DONSKOY','VERDASCO','CORIC','THIEM','HERBERT','POLANSKY',
                'QUERREY','CARRENO','FOGNINI','YOUZHNY','HARRISON','ALIASSIME','RAONIC','FUCSOVICS'],
               
                '2019':['NADAL','MEDVEDEV','MONFILS','KHACHANOV',
                        'FOGNINI','THIEM','ZVEREV','BAUTISTA',
                'PELLA','CILIC','BASILASHVILI','ALIASSIME','MANNARINO','GARIN','GASQUET','HURKACZ',
                'EVANS','SHAPOVALOV','NORRIE','TSITSIPAS','NISHIKORI','WAWRINKA','PAUL','EDMUND',
                'SCHWARTZMAN','CORIC','ISNER','STRUFF','MILLMAN','IVASHKA','RAONIC','ALBOT'],
               
                '2020': lista_NaN,
               
                '2021': lista_NaN }

# %%
Canada_PLACEMENTS_DATA = pd.DataFrame( CANADA_dict )
Canada_PLACEMENTS_DATA = Canada_PLACEMENTS_DATA.T
Canada_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Canada_PLACEMENTS_DATA
# Out:
#         winner   finalist      semi1       semi2        q1        q2  \
# 2014    TSONGA    FEDERER      LOPEZ    DIMITROV    FERRER    RAONIC
# 2015    MURRAY   DJOKOVIC     CHARDY   NISHIKORI    GULBIS    TSONGA
# 2016  DJOKOVIC  NISHIKORI    MONFILS    WAWRINKA   BERDYCH  ANDERSON
# 2017    ZVEREV    FEDERER      HAASE  SHAPOVALOV  BAUTISTA  ANDERSON
# 2018     NADAL  TSITSIPAS  KHACHANOV    ANDERSON     CILIC    ZVEREV
# 2019     NADAL   MEDVEDEV    MONFILS   KHACHANOV   FOGNINI     THIEM
# 2020       NaN        NaN        NaN         NaN       NaN       NaN
# 2021       NaN        NaN        NaN         NaN       NaN       NaN
#
#                q3         q4        o1        o2  ...          32_7      32_8  \
# 2014     ANDERSON     MURRAY  DJOKOVIC     CILIC  ...         YOUNG   KYRGIOS
# 2015        NADAL      ISNER      SOCK    MULLER  ...    STAKHOVSKY    RAONIC
# 2016     DIMITROV     RAONIC  STEPANEK      SOCK  ...       QUERREY     CILIC
# ...

# %%
Canada_PLACEMENTS_DATA.to_excel("Canada_PLACEMENTS_DATA.xlsx")
