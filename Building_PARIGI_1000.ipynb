# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Parigi_1000_dict = {'2014':['DJOKOVIC','RAONIC','NISHIKORI','BERDYCH',
                            'MURRAY','FEDERER','FERRER','ANDERSON',
                    'MONFILS','POUILLE','WAWRINKA','VERDASCO','LOPEZ','TSONGA','BAUTISTA','DIMITROV',
                    'KOHLSCHREIBER','CHARDY','THIEM','GOFFIN','MANNARINO','ROBREDO','SOCK','BENNETEAU',
                    'CUEVAS','MELZER','GASQUET','QUERREY','ISNER','GIRALDO','SIMON','FOGNINI'],
                   
                    '2015':['DJOKOVIC','MURRAY','WAWRINKA','FERRER',
                            'BERDYCH','GASQUET','NADAL','ISNER',
                    'SIMON','GOFFIN','FEDERER','TROICKI','TSONGA','NISHIKORI','ANDERSON','DIMITROV',
                    'BELLUCCI','CORIC','SEPPI','TOMIC','VASSELIN','CHARDY','ROSOL','DOLGOPOLOV',
                    'BAUTISTA','MAYER','THIEM','CILIC','BEDENE','PAIRE','LOPEZ','LAJOVIC'],
                   
                    '2016':['MURRAY','ISNER','RAONIC','CILIC',
                            'DJOKOVIC','BERDYCH','TSONGA','SOCK',
                    'DIMITROV','POUILLE','CUEVAS','NISHIKORI','SIMON','GOFFIN','GASQUET','STRUFF',
                    'MULLER','VERDASCO','WAWRINKA','CARRENO','TROICKI','THIEM','SOUSA','MAHUT',
                    'KARLOVIC','BAUTISTA','VINOLAS','JOHNSON','LOPEZ','BAGHDATIS','FERRER','LORENZI'],
                   
                    '2017':['SOCK','KRAJINOVIC','ISNER','BENNETEAU',
                            'NADAL','CILIC','DelPOTRO','VERDASCO',
                    'CUEVAS','BAUTISTA','THIEM','DIMITROV','GOFFIN','HAASE','POUILLE','MAHUT',
                    'CHUNG','CORIC','ZVEREV','GOJOWCZYK','GASQUET','MANNARINO','CARRENO','SCHWARTZMAN',
                    'QUERREY','TSONGA','ANDERSON','SOUSA','CHARDY','VINOLAS','EDMUND','LOPEZ'],
                   
                    '2018':['KHACHANOV','DJOKOVIC','FEDERER','THIEM',
                            'CILIC','NISHIKORI','ZVEREV','SOCK',
                    'DZUMHUR','FOGNINI','SCHWARTZMAN','DIMITROV','CORIC','ANDERSON','ISNER','JAZIRI',
                    'SOUSA','RAONIC','TIAFOE','KOHLSCHREIBER','SIMON','BASILASHVILI','KUKUSHKIN','BAUTISTA',
                    'MANNARINO','MEDVEDEV','FUCSOVICS','TSITSIPAS','LOPEZ','GASQUET','VERDASCO','EBDEN'],
                   
                    '2019':['DJOKOVIC','SHAPOVALOV','DIMITROV','NADAL',
                            'TSITSIPAS','TSONGA','MONFILS','GARIN',
                    'EDMUND','WAWRINKA','THIEM','ZVEREV','DeMINAUR','ALBOT','CHARDY','STRUFF',
                    'MOUTET','MANNARINO','MEDVEDEV','RAONIC','VERDASCO','FRITZ','KHACHANOV','BAUTISTA',
                    'BERRETTINI','FOGNINI','GOFFIN','PAIRE','SCHWARTZMAN','ISNER','CILIC','SEPPI'],
                   
                    '2020':['MEDVEDEV','ZVEREV','NADAL','RAONIC',
                            'CARRENO','SCHWARTZMAN','WAWRINKA','HUMBERT',
                    'THOMPSON','DeMINAUR','MANNARINO','RUBLEV','FOKINA','GOMBOS','GIRON','CILIC',
                    'LOPEZ','TSITSIPAS','ANDERSON','KECMANOVIC','ALBOT','GASQUET','BERRETTINI','GOFFIN',
                    'STRUFF','HERBERT','PAUL','CORIC','SONEGO','MOUTET','BONZI','NISHIOKA'],
                   
                    '2021': lista_NaN }

# %%
Parigi_1000_PLACEMENTS_DATA = pd.DataFrame( Parigi_1000_dict )
Parigi_1000_PLACEMENTS_DATA = Parigi_1000_PLACEMENTS_DATA.T
Parigi_1000_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Parigi_1000_PLACEMENTS_DATA
# Out:
#          winner    finalist      semi1      semi2         q1           q2  \
# 2014   DJOKOVIC      RAONIC  NISHIKORI    BERDYCH     MURRAY      FEDERER
# 2015   DJOKOVIC      MURRAY   WAWRINKA     FERRER    BERDYCH      GASQUET
# 2016     MURRAY       ISNER     RAONIC      CILIC   DJOKOVIC      BERDYCH
# 2017       SOCK  KRAJINOVIC      ISNER  BENNETEAU      NADAL        CILIC
# 2018  KHACHANOV    DJOKOVIC    FEDERER      THIEM      CILIC    NISHIKORI
# 2019   DJOKOVIC  SHAPOVALOV   DIMITROV      NADAL  TSITSIPAS       TSONGA
# 2020   MEDVEDEV      ZVEREV      NADAL     RAONIC    CARRENO  SCHWARTZMAN
# 2021        NaN         NaN        NaN        NaN        NaN          NaN
#
#             q3        q4        o1        o2  ...        32_7         32_8  \
# 2014    FERRER  ANDERSON   MONFILS   POUILLE  ...        SOCK    BENNETEAU
# 2015     NADAL     ISNER     SIMON    GOFFIN  ...       ROSOL   DOLGOPOLOV
# 2016    TSONGA      SOCK  DIMITROV   POUILLE  ...       SOUSA        MAHUT
# ...

# %%
Parigi_1000_PLACEMENTS_DATA.to_excel("Parigi_1000_PLACEMENTS_DATA.xlsx")
