# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(32) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 32
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Miami_placement_dict = {'2014':['DJOKOVIC','NADAL','BERDYCH','NISHIKORI',
                                'RAONIC','MURRAY','FEDERER','DOLGOPOLOV',
                        'FOGNINI','ROBREDO','WAWRINKA','FERRER','GASQUET','TSONGA','ISNER','BECKER',
                        'ISTOMIN','FlorianMAYER','VASELLIN','SEPPI','DeBAKKER','LOPEZ','SOUSA','ANDERSON',
                        'ALMAGRO','BAGHDATIS','GARCIA','BAUTISTA','DIMITROV','BENNETEAU','LAJOVIC','BEDENE'],
                        
                        '2015':['DJOKOVIC','MURRAY','ISNER','BERDYCH',
                                'FERRER','THIEM','NISHIKORI','MONACO',
                        'DOLGOPOLOV','ANDERSON','GOFFIN','RAONIC','SIMON','MONFILS','MANNARINO','VERDASCO',
                        'DARCIS','NADAL','GIRALDO','TROICKI','CHARDY','ROSOL','WAWRINKA','TOMIC',
                        'DIMITROV','TSONGA','FALLA','MAYER','JANOWICZ','GARCIA','BELLUCCI','SOCK'],
                        
                        '2016':['DJOKOVIC','NISHIKORI','GOFFIN','KYRGIOS',
                                'BERDYCH','MONFILS','RAONIC','SIMON',
                        'THIEM','BAUTISTA','GASQUET','DZUMHUR','ZEBALLOS','DIMITROV','POUILLE','KUZNETSOV',
                        'SOUSA','MURRAY','DOLGOPOLOV','JOHNSON','FERRER','TSONGA','PAIRE','CILIC',
                        'SOCK','NISHIOKA','TROICKI','CUEVAS','SMYCZEK','KUKUSHKIN','MANNARINO','VERDASCO'],
                        
                        '2017':['FEDERER','NADAL','KYRGIOS','FOGNINI',
                                'NISHIKORI','BERDYCH','SOCK','ZVEREV',
                        'WAWRINKA','DelBONIS','BAUTISTA','MAHUT','GOFFIN','MANNARINO','DONALDSON','YOUNG',
                        'JAZIRI','VERDASCO','RAONIC','DelPOTRO','KOHLSCHREIBER','SCHWARTZMAN','MULLER','KARLOVIC',
                        'VESELY','QUERREY','ISNER','STRUFF','CHARDY','PELLA','CORIC','PAIRE'],
                        
                        '2018':['ISNER','ZVEREV','CARRENO','DelPOTRO',
                                'CORIC','RAONIC','ANDERSON','CHUNG',
                        'CILIC','KYRGIOS','KRAJINOVIC','TIAFOE','VERDASCO','SOUSA','CHARDY','SHAPOVALOV',
                        'POSPISIL','DIMITROV','FERRER','NISHIKORI','KHACHANOV','SOCK','BERDYCH','QUERREY',
                        'SCHWARTZMAN','YOUZHNY','FOGNINI','JOHNSON','MMOH','PAIRE','KOKKINAKIS','DONALDSON'],
    
                        '2019':['FEDERER','ISNER','SHAPOVALOV','ALIASSIME',
                                'ANDERSON','BAUTISTA','CORIC','TIAFOE',
                        'DJOKOVIC','MEDVEDEV','THOMPSON','EDMUND','TSITSIPAS','KYRGIOS','BASILASHVILI','GOFFIN',
                        'DelBONIS','KRAJINOVIC','SOUSA','VINOLAS','MAYER','CHARDY','RAONIC','OPELKA',
                        'CECCHINATO','FOGNINI','HAASE','RUBLEV','DIMITROV','LAJOVIC','FERRER','HURKACZ'],
                        
                        '2020':lista_NaN,
                       
                        '2021':['HURKACZ','SINNER','RUBLEV','BAUTISTA',
                                'MEDVEDEV','TSITSIPAS','KORDA','BUBLIK',
                        'TIAFOE','SONEGO','CILIC','SCHWARTZMAN','ISNER','RAONIC','RUUSUVUORI','FRITZ',
                        'POPYRIN','NISHIKORI','FUCSOVICS','MANNARINO','SHAPOVALOV','STRUFF','ALIASSIME','HUMBERT',
                        'KHACHANOV','LAJOVIC','KARATSEV','NORRIE','GALAN','DUCKWORTH','MUSETTI','YMER'] }

# %%
Miami_PLACEMENTS_DATA = pd.DataFrame( Miami_placement_dict )
Miami_PLACEMENTS_DATA = Miami_PLACEMENTS_DATA.T
Miami_PLACEMENTS_DATA.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16']
Miami_PLACEMENTS_DATA
# Out:
#         winner   finalist       semi1      semi2         q1         q2  \
# 2014  DJOKOVIC      NADAL     BERDYCH  NISHIKORI     RAONIC     MURRAY
# 2015  DJOKOVIC     MURRAY       ISNER    BERDYCH     FERRER      THIEM
# 2016  DJOKOVIC  NISHIKORI      GOFFIN    KYRGIOS    BERDYCH    MONFILS
# 2017   FEDERER      NADAL     KYRGIOS    FOGNINI  NISHIKORI    BERDYCH
# 2018     ISNER     ZVEREV     CARRENO   DelPOTRO      CORIC     RAONIC
# 2019   FEDERER      ISNER  SHAPOVALOV  ALIASSIME   ANDERSON   BAUTISTA
# 2020       NaN        NaN         NaN        NaN        NaN        NaN
# 2021   HURKACZ     SINNER      RUBLEV   BAUTISTA   MEDVEDEV  TSITSIPAS
#
#              q3          q4          o1        o2  ...       32_7      32_8  \
# 2014    FEDERER  DOLGOPOLOV     FOGNINI   ROBREDO  ...      SOUSA  ANDERSON
# 2015  NISHIKORI      MONACO  DOLGOPOLOV  ANDERSON  ...   WAWRINKA     TOMIC
# 2016     RAONIC       SIMON       THIEM  BAUTISTA  ...      PAIRE     CILIC
# ...

# %%
Miami_PLACEMENTS_DATA.to_excel("Miami_PLACEMENTS_DATA.xlsx")
