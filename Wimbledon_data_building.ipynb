# %%
NaN_str = 'NaN'
lista_NaN = []

for v in range(64) :
    lista_NaN.append( NaN_str )

print( len( lista_NaN ) )
print( lista_NaN )
# Out:
# 64
# ['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN']

# %%
import pandas as pd
import numpy as np

Wimbledon_placement_data_dict = {'2021':lista_NaN,
                                
                                 '2020':lista_NaN,
                                
                                 '2019':['DJOKOVIC','FEDERER','BAUTISTA','NADAL',
                                         'GOFFIN','NISHIKORI','QUERREY','PELLA',
                                 'HUMBERT','BERRETTINI','SOUSA','KUKUSHKIN','RAONIC','VERDASCO','PAIRE','SANDGREN',
                                 'HURKACZ','POUILLE','TSONGA','ANDERSON','JOHNSON','KHACHANOV','MEDVEDEV','FOGNINI',
                                 'OPELKA','SCHWARTZMAN','ALIASSIME','VESELY','STRUFF','MILLMAN','EVANS','FABBIANO',
                                 'KUDLA','CLARKE','KYRGIOS','TIPSAREVIC','NORRIE','ISNER','LOPEZ','POPYRIN',
                                 'FUCSOVICS','CILIC','HAASE','BAGHDATIS','BASILASHVILI','MOUTET','SIMON','CHARDY',
                                 'WAWRINKA','DARCIS','KOEPFER','DeMINAUR','SEPPI','BARRERE','KECMANOVIC','EDMUND',
                                 'DJERE','FRITZ','KARLOVIC','GRANOLLERS','MAYER','RUBLEV','BERANKIS','CUEVAS'],
                                
                                 '2018':['DJOKOVIC','ANDERSON','NADAL','ISNER',
                                         'FEDERER','DelPOTRO','RAONIC','NISHIKORI',
                                 'MANNARINO','VESELY','SIMON','MONFILS','TSITSIPAS','KHACHANOV','McDONALD','GULBIS',
                                 'STRUFF','DeMINAUR','ZVEREV','PAIRE','KOHLSCHREIBER','ALBOT','QUERREY','EDMUND',
                                 'NOVAK','KYRGIOS','FOGNINI','MEDVEDEV','FABBIANO','TIAFOE','PELLA','EBDEN',
                                 'LACKO','KUKUSHKIN','CILIC','FRITZ','LOPEZ','SEPPI','BEMELMANS','STAKHOVSKY',
                                 'ZEBALLOS','MILLMAN','SCHWARTZMAN','HAASE','POUILLE','BOLELLI','KLAHN','HARRISON',
                                 'TOMIC','MULLER','SHAPOVALOV','DZUMHUR','DONALDSON','BEDENE','HERBERT','ROBERT',
                                 'WAWRINKA','BAGHDATIS','JARRY','GARCIA','LORENZI','BERRETTINI','KARLOVIC','BENNETEAU'],
                                
                                 '2017':['FEDERER','CILIC','BERDYCH','QUERREY',
                                         'MURRAY','DJOKOVIC','RAONIC','MULLER',
                                 'PAIRE','MANNARINO','DIMITROV','NADAL','ZVEREV','BAUTISTA','THIEM','ANDERSON',
                                 'FOGNINI','GULBIS','MischaZVEREV','KHACHANOV','VINOLAS','JOHNSON','DONALDSON','NISHIKORI',
                                 'OFNER','FERRER','TSONGA','SELA','MONFILS','BEDENE','BEMELMANS','JANOWICZ',
                                 'BROWN','PAVLASEK','LAJOVIC','YOUNG','YOUZHNY','FlorianMAYER','SIMON','STAKHOVSKY',
                                 'TIAFOE','HARRISON','BOLELLI','BAGHDATIS','POUILLE','EDMUND','ROSOL','SOCK',
                                 'GOJOWCZYK','ISNER','BASILASHVILI','RUBLEV','ALBOT','KUKUSHKIN','VESELY','DelPOTRO',
                                 'MONTEIRO','LORENZI','SEPPI','DZUMHUR','MEDVEDEV','DARCIS','SUGITA','HERBERT'],
                                
                                 '2016':['MURRAY','RAONIC','BERDYCH','FEDERER',
                                         'TSONGA','CILIC','QUERREY','POUILLE',
                                 'KYRGIOS','JOHNSON','NISHIKORI','GOFFIN','GASQUET','VESELY','TOMIC','MAHUT',
                                 'DJOKOVIC','MILLMAN','EVANS','KUZNETSOV','SOCK','VINOLAS','LACKO','ZVEREV',
                                 'ISTOMIN','ISNER','BAUTISTA','LOPEZ','SOUSA','DelPOTRO','DIMITROV','HERBERT',
                                 'MANNARINO','LU','WILLIS','WAWRINKA','BENNETEAU','SEPPI','GRANOLLERS','THIEM',
                                 'STAKHOVSKY','BECKER','VASELLIN','MONACO','FERRER','KUKUSHKIN','BROWN','SIMON',
                                 'BARTON','ALBOT','FOGNINI','KARLOVIC','YOUZHNY','TROICKI','PAIRE','HAASE',
                                 'BELLUCCI','DOLGOPOLOV','NOVIKOV','YOUNG','DZUMHUR','ALMAGRO','CHARDY','MULLER'],
                                
                                 '2015':['DJOKOVIC','FEDERER','GASQUET','MURRAY',
                                         'CILIC','SIMON','POSPISIL','WAWRINKA',
                                 'ANDERSON','BAUTISTA','KARLOVIC','GOFFIN','BERDYCH','KUDLA','KYRGIOS','TROICKI',
                                 'TOMIC','GROTH','SEPPI','VERDASCO','ANDUJAR','RAONIC','ISNER','DIMITROV',
                                 'MONFILS','TSONGA','MAYER','BAGHDATIS','BASILASHVILI','BROWN','GIRALDO','WARD',
                                 'NIEMINEN','QUERREY','HAASE','EstrellaBURGOS','NISHIKORI','MAHUT','HAAS','BERANKIS',
                                 'NADAL','JOHNSON','KAVCIC','VINOLAS','ILHAN','LOPEZ','BROADY','EBDEN',
                                 'MANNARINO','PAIRE','DeSCHEPPER','BEDENE','DOLGOPOLOV','GRANOLLERS','CORIC','MONACO',
                                 'HERBERT','FOGNINI','THIEM','ROSOL','MILLMAN','DUCKWORTH','ZVEREV','VESELY'],
                                
                                 '2014':['DJOKOVIC','FEDERER','DIMITROV','RAONIC',
                                         'CILIC','MURRAY','WAWRINKA','KYRGIOS',
                                 'TSONGA','NADAL','ANDERSON','ROBREDO','LOPEZ','NISHIKORI','MAYER','CHARDY',
                                 'SIMON','KUKUSHKIN','BAUTISTA','GIRALDO','ISTOMIN','BERDYCH','KUBOT','ISNER',
                                 'BOLELLI','DOLGOPOLOV','WANG','JANOWICZ','FOGNINI','STAKHOVSKY','VESELY','KUZNETSOV',
                                 'STEPANEK','ROSOL','ROLA','MULLER','LU','TOMIC','FERRER','SOCK',
                                 'NIEMINEN','KUDLA','SAVILLE','GULBIS','GASQUET','QUERREY','HEWITT','PUETZ',
                                 'YOUZHNY','PAVIC','VASSELIN','BECKER','KOHLSCHREIBER','MANNARINO','MONFILS','HaiderMAURER',
                                 'HERNYCH','GRANOLLERS','MATOSEVIC','REISTER','LAJOVIC','DANCEVIC','BAGHDATIS','HAASE'] }

# %%
Wimbledon_data = pd.DataFrame( Wimbledon_placement_data_dict )
Wimbledon_data = Wimbledon_data.T
Wimbledon_data.columns=['winner','finalist','semi1','semi2','q1','q2','q3','q4',
                                         'o1','o2','o3','o4','o5','o6','o7','o8',
                                         '32_1','32_2','32_3','32_4','32_5','32_6','32_7','32_8',
                                         '32_9','32_10','32_11','32_12','32_13','32_14','32_15','32_16',
                                         '64_1','64_2','64_3','64_4','64_5','64_6','64_7','64_8',
                                         '64_9','64_10','64_11','64_12','64_13','64_14','64_15','64_16',
                                         '64_17','64_18','64_19','64_20','64_21','64_22','64_23','64_24',
                                         '64_25','64_26','64_27','64_28','64_29','64_30','64_31','64_32']
Wimbledon_data
# Out:
#         winner  finalist     semi1    semi2       q1         q2        q3  \
# 2021       NaN       NaN       NaN      NaN      NaN        NaN       NaN
# 2020       NaN       NaN       NaN      NaN      NaN        NaN       NaN
# 2019  DJOKOVIC   FEDERER  BAUTISTA    NADAL   GOFFIN  NISHIKORI   QUERREY
# 2018  DJOKOVIC  ANDERSON     NADAL    ISNER  FEDERER   DelPOTRO    RAONIC
# 2017   FEDERER     CILIC   BERDYCH  QUERREY   MURRAY   DJOKOVIC    RAONIC
# 2016    MURRAY    RAONIC   BERDYCH  FEDERER   TSONGA      CILIC   QUERREY
# 2015  DJOKOVIC   FEDERER   GASQUET   MURRAY    CILIC      SIMON  POSPISIL
# 2014  DJOKOVIC   FEDERER  DIMITROV   RAONIC    CILIC     MURRAY  WAWRINKA
#
#              q4         o1          o2  ...       64_23         64_24  \
# 2021        NaN        NaN         NaN  ...         NaN           NaN
# 2020        NaN        NaN         NaN  ...         NaN           NaN
# 2019      PELLA    HUMBERT  BERRETTINI  ...  KECMANOVIC        EDMUND
# ...

# %%
Wimbledon_data.to_excel("Wimbledon_data.xlsx")
